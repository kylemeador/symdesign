# %% [markdown]
# # Start you dataset visualization here
# ### modify the analysis_file to the string where the dataframe file (.csv) produced by SymDesign.py analysis lives and the filter_file variable to the provided symdesign/data/filter_and_sort_df.csv

# %%
# !pwd
# Out:
# /home/kylemeador/symdesign/jupyter_notebooks

# %%
analysis_file = '/home/kylemeador/designs/T33/AllDesignPoseMetrics_Total.csv' # YOUR ANALYSIS FILE HERE
filter_file = '/home/kylemeador/symdesign/data/filter_and_sort_df.csv'

# %% [markdown]
# Import the required packages

# %%
import os
import math
import operator
from itertools import combinations

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Magic methods ensure any changes to imported files stay current in the notebook

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
mean = 'mean'
std = 'std'
idx = pd.IndexSlice

# %%
def columns_to_new_column(df, column_dict, mode='add'):
    """Find new column values by taking an operation of one column on another

    Args:
        df (pandas.DataFrame): Dataframe where the columns are located
        column_dict (dict): A dictionary with keys as new column names, values as tuple of columns.
            Where value[0] mode(operation) value[1] = key
    Keyword Args:
        mode='add' (str) = What operator to use?
            Viable options are included in module operator, but could be 'sub', 'mul', 'truediv', etc.
    Returns:
        df (pandas.DataFrame): Dataframe with new column values
    """
    for column in column_dict:
        try:
            df[column] = operator.attrgetter(mode)(operator)(df[column_dict[column][0]], df[column_dict[column][1]])
        except KeyError:
            pass

    return df

# %%
# need {column: {'direction': 'max', 'val': 0.5, 'idx': []}, ...}
def df_filter_index_by_value(df, **kwargs):
    """Take a df and retrieve the indices which have column values greater_equal/less_equal to a value depending
    on whether the column should be sorted max/min
    Args:
        df (pandas.DataFrame): DataFrame to filter indices on
    Keyword Args:
        kwargs (dict): {column: {'direction': 'min', 'value': 0.3, 'idx': ['0001', '0002', ...]}, ...}
    """
    indices_l = []
    for _index in kwargs:
        if kwargs[_index]['direction'] == 'max':
            kwargs[_index]['idx'] = df[df[_index] >= kwargs[_index]['value']].index.to_list()
        if kwargs[_index]['direction'] == 'min':
            kwargs[_index]['idx'] = df[df[_index] <= kwargs[_index]['value']].index.to_list()
    
    return kwargs

# %%
def index_intersection(filtered_indices):
    """Take the intersection of provided indices in key, value pairs
    
    Args:
        filtered_indices (dict): {metric: indices, ...}
    Returns:
        (list): All indices in each provided metric
    """
    final_indices = set()
    # find all set union
    for metric in filtered_indices:
        final_indices = set(final_indices) | set(filtered_indices[metric])
        
    # find all set intersection
    for metric in filtered_indices:
        final_indices = set(final_indices) & set(filtered_indices[metric])
    return list(final_indices)

# %%
def return_df_feature_descriptors(df):
    """From a dataframe, return only the numeric features (columns) and their statistcial descriptions
    
    Returns:
        (pandas.DataFrame)
    """
    numerical_df = df.apply(lambda x: pd.to_numeric(x, errors='coerce')).dropna(axis=1)
    measures = {'mean': numerical_df.mean(), 
                'std': numerical_df.std(),
                'min': numerical_df.min(),
                'max': numerical_df.max()}
    descriptor_df = pd.DataFrame(measures)
    descriptor_df['range'] = descriptor_df['max'] - descriptor_df['min']
    return pd.concat([descriptor_df], keys=['descriptors'], axis=1)

# %% [markdown]
# Importing filter_key

# %%
filter_key_df = pd.read_csv(filter_file, index_col=0)
display(filter_key_df)
# Out:
#           buns_per_ang buns_heavy_total buns_hpol_total buns_total  \
# direction          min              min             min        min
# function     normalize             rank            rank       rank
# filter            TRUE             TRUE            TRUE       TRUE
#
#           component_1_number_of_residues component_1_symmetry  \
# direction                            max                  min
# function                            rank               equals
# filter                              TRUE                 TRUE
#
#           component_2_number_of_residues component_2_symmetry contact_count  \
# direction                            min                  min           max
# function                            rank               equals          rank
# filter                              TRUE                 TRUE          TRUE
#
#           cst_weight fsp_energy fsp_total_stability full_stability  \
# direction        min        max                 min            min
# function   normalize  normalize           normalize      normalize
# filter         FALSE      FALSE               FALSE          FALSE
#
#           int_area_hydrophobic int_area_polar  \
# direction                  min            max
# function                  rank           rank
# filter                    TRUE           TRUE
#
#           int_area_res_summary_hydrophobic_1_unbound  \
# direction                                        min
# function                                        rank
# filter                                          TRUE
#
#           int_area_res_summary_hydrophobic_2_unbound  \
# direction                                        min
# function                                        rank
# filter                                          TRUE
#
#           int_area_res_summary_polar_1_unbound  \
# direction                                  max
# function                                  rank
# filter                                    TRUE
#
#           int_area_res_summary_polar_2_unbound  \
# direction                                  max
# function                                  rank
# filter                                    TRUE
#
#           int_area_res_summary_total_1_unbound  \
# direction                                  max
# function                                  rank
# filter                                    TRUE
#
#           int_area_res_summary_total_2_unbound int_area_total  \
# direction                                  max            max
# function                                  rank           rank
# filter                                    TRUE           TRUE
#
#           int_composition_similarity int_connectivity_1 int_connectivity_2  \
# direction                        max                max                max
# function                        rank          normalize          normalize
# filter                          TRUE               TRUE               TRUE
#
#           int_energy_context_1_unbound int_energy_context_2_unbound  \
# direction                          max                          max
# function                     normalize                    normalize
# filter                           FALSE                        FALSE
#
#           int_energy_context_complex int_energy_context_delta  \
# direction                        min                      min
# function                        rank                     rank
# filter                          TRUE                     TRUE
#
#           int_energy_context_unbound int_energy_res_summary_complex  \
# direction                        min                            min
# function                        rank                           rank
# filter                          TRUE                          FALSE
#
#           int_energy_res_summary_delta int_energy_res_summary_unbound  \
# direction                          min                            min
# function                          rank                           rank
# filter                            TRUE                          FALSE
#
#           int_energy_res_summary_1_unbound int_energy_res_summary_2\n_unbound  \
# direction                              min                                min
# function                              rank                               rank
# filter                               FALSE                              FALSE
#
#           int_separation interaction_energy_complex multiple_fragment_ratio  \
# direction            min                        min                     max
# function       normalize                       rank                    rank
# filter              TRUE                       TRUE                    TRUE
#
#           nanohedra_score nanohedra_score_central nanohedra_score_per_res  \
# direction             max                     max                     max
# function             rank                    rank                    rank
# filter               TRUE                    TRUE                    TRUE
#
#           number_hbonds number_fragment_residues_central  \
# direction           max                              max
# function           rank                             rank
# filter             TRUE                             TRUE
#
#           number_fragment_residues_total observed_design observed_evolution  \
# direction                            max             max                max
# function                            rank            rank               rank
# filter                              TRUE            TRUE               TRUE
#
#           observed_fragment percent_int_area_hydrophobic  \
# direction               max                          min
# function               rank                    normalize
# filter                 TRUE                         TRUE
#
#           percent_int_area_polar percent_core percent_fragment  \
# direction                    max          max              max
# function               normalize    normalize        normalize
# filter                      TRUE         TRUE             TRUE
#
#           percent_fragment_coil percent_fragment_helix  \
# direction                   max                    max
# function              normalize              normalize
# filter                     TRUE                   TRUE
#
#           percent_fragment_strand percent_residues_fragment_total  \
# direction                     max                             max
# function                normalize                       normalize
# filter                       TRUE                            TRUE
#
#           percent_residues_fragment_center percent_rim percent_support  \
# direction                              max         min             max
# function                         normalize   normalize       normalize
# filter                                TRUE        TRUE            TRUE
#
#           protocol_energy_distance_sum protocol_seq_distance_sum  \
# direction                          min                       min
# function                          rank                      rank
# filter                            TRUE                      TRUE
#
#           protocol_similarity_sum    ref       rmsd shape_complementarity  \
# direction                     max    max        min                   max
# function                     rank   rank  normalize             normalize
# filter                       TRUE  FALSE       TRUE                  TRUE
#
#           solvation_energy average_fragment_z_score  \
# direction              min                      min
# function            rank\n                normalize
# filter              TRUE\n                     TRUE
#
#           interface_b_factor_per_res observations total_interface_residues  \
# direction                        max          max                      max
# function                        rank         rank                     rank
# filter                         FALSE         TRUE                     TRUE
#
#           unique_fragments  core divergence_design_per_res  \
# direction              max   max                       min
# function              rank  rank                      rank
# filter                TRUE  TRUE                      TRUE
#
#           divergence_evolution_per_res divergence_fragment_per_res  \
# direction                          min                         min
# function                          rank                        rank
# filter                            TRUE                        TRUE
#
#           divergence_interface_per_res   rim support  Unnamed: 78
# direction                          min   max     max          NaN
# function                          rank  rank    rank          NaN
# filter                            TRUE  TRUE    TRUE          NaN

# %%
df = pd.read_csv(analysis_file, index_col=0, header=[0,1,2])

# %%
df = df.rename_axis(columns=['protocol', 'measure', 'metric'])
print('Starting size')
display(df.shape)
# outliers = (df.loc[:, idx['pose', mean, 'int_energy_res_summary_unbound']] >= 10)  # .any(axis=1) if using multiple columns
# df = df.loc[~outliers, :]  # .any(axis=0)
# print('Removing energy outliers')
# display(df.shape)
df.dropna(inplace=True)
print('Removing missing values')
display(df.shape)
# Out:
# Starting size
# (493874, 27)
# Removing missing values
# (493874, 27)

# %% [markdown]
# ## Visualize data descriptors (mean, standard deviation, min, max, range) for the dataframe

# %%
df.rename(columns={'unique_fragments': 'number_fragments', 'nanohedra_score_per_res': 'nanohedra_score_center_per_res_center',
                   'number_fragment_residues_central': 'number_fragment_residues_center',
                   'nanohedra_score_central': 'nanohedra_score_center'}, inplace=True)

# %%
df
# Out:
# protocol                                                           pose  \
# measure                                                            dock
# metric                               component_1_c_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                 -1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                 -1
#
# protocol                                                     \
# measure
# metric                               component_1_max_radius
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210              76.821750
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              75.572927
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213              75.307815
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215              75.261429
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191              76.159011
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140              73.604927
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145              73.967036
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149              73.773559
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151              73.699158
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203              75.331008
#
# protocol                                                                 \
# measure
# metric                               component_1_n_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                               \
# measure
# metric                               component_1_name
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191           4MI2_1
# ...                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203           4MI2_1
#
# protocol                                                             \
# measure
# metric                               component_1_number_of_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                            260
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                            260
#
# protocol                                                   \
# measure
# metric                               component_1_symmetry
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   C3
# ...                                                   ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   C3
#
# protocol                                                                 \
# measure
# metric                               component_2_c_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                                     \
# measure
# metric                               component_2_max_radius
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210              53.564332
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              54.497854
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213              54.096864
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215              54.256571
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191              48.047899
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140              51.189786
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145              51.421290
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149              51.410586
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151              50.019126
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203              54.628992
#
# protocol                                                                 \
# measure
# metric                               component_2_n_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                               \
# measure
# metric                               component_2_name
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191           4M1A_1
# ...                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203           4M1A_1
#
# protocol                                                             \
# measure
# metric                               component_2_number_of_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                            106
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                            106
#
# protocol                                                                    \
# measure
# metric                               component_2_symmetry design_dimension
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   C3                0
# ...                                                   ...              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   C3                0
#
# protocol                                                         \
# measure
# metric                               interface_b_factor_per_res
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                       20.0
# ...                                                         ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                       20.0
#
# protocol                                                                      \
# measure
# metric                               multiple_fragment_ratio nanohedra_score
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                3.666667       17.797829
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                3.555556       19.917511
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                4.000000       18.144322
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                3.777778       18.692283
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                2.363636       24.027251
# ...                                                      ...             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                3.777778       20.999764
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                3.500000       21.938419
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                3.500000       21.219092
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                4.222222       21.547762
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                4.222222       19.590534
#
# protocol                                                     \
# measure
# metric                               nanohedra_score_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210               5.939412
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              10.124070
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213               8.033094
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215               9.506577
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191               8.484664
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140               6.802112
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145               6.056401
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149               5.879402
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151               7.644833
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203               9.909078
#
# protocol                                                                    \
# measure
# metric                               nanohedra_score_center_per_res_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                              0.989902
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                              1.124897
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                              1.004137
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                              1.056286
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                              0.771333
# ...                                                                    ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                              0.755790
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                              0.757050
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                              0.734925
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                              0.849426
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                              1.101009
#
# protocol                                                              \
# measure
# metric                               number_fragment_residues_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                               6
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                              11
# ...                                                              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                               9
#
# protocol                                                             \
# measure
# metric                               number_fragment_residues_total
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                             18
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                             35
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                             31
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                             30
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                             30
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                             29
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                             19
#
# protocol                                                    \
# measure
# metric                               percent_fragment_coil
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   0.0
# ...                                                    ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   0.0
#
# protocol                                                     \
# measure
# metric                               percent_fragment_helix
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                    1.0
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                    1.0
#
# protocol                                                      \
# measure
# metric                               percent_fragment_strand
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                     0.0
# ...                                                      ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                     0.0
#
# protocol                                                               \
# measure
# metric                               percent_residues_fragment_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                         0.193548
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                         0.187500
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                         0.156863
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                         0.173077
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                         0.440000
# ...                                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                         0.140625
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                         0.131148
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                         0.125000
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                         0.147541
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                         0.173077
#
# protocol                                                              \
# measure
# metric                               percent_residues_fragment_total
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                        0.580645
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                        0.395833
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                        0.372549
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                        0.365385
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                        1.400000
# ...                                                              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                        0.484375
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                        0.491803
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                        0.468750
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                        0.475410
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                        0.365385
#
# protocol
# measure
# metric                               total_interface_residues number_fragments
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                       31               11
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                       48               16
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                       51               16
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                       52               17
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                       25               13
# ...                                                       ...              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                       64               17
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                       61               14
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                       64               14
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                       61               19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                       52               19
#
# [493874 rows x 27 columns]

# %%
df[('pose', 'dock', 'nanohedra_score_per_res')] = df[('pose', 'dock', 'nanohedra_score')] / df [('pose', 'dock', 'number_fragment_residues_total')]
df[('pose', 'dock', 'non_fragment_residues')] = df[('pose', 'dock', 'total_interface_residues')] - df [('pose', 'dock', 'number_fragment_residues_center')]
# display(df)
# Out:
# protocol                                                           pose  \
# measure                                                            dock
# metric                               component_1_c_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                 -1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                 -1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                 -1
#
# protocol                                                     \
# measure
# metric                               component_1_max_radius
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210              76.821750
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              75.572927
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213              75.307815
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215              75.261429
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191              76.159011
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140              73.604927
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145              73.967036
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149              73.773559
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151              73.699158
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203              75.331008
#
# protocol                                                                 \
# measure
# metric                               component_1_n_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                               \
# measure
# metric                               component_1_name
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191           4MI2_1
# ...                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151           4MI2_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203           4MI2_1
#
# protocol                                                             \
# measure
# metric                               component_1_number_of_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                            260
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                            260
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                            260
#
# protocol                                                   \
# measure
# metric                               component_1_symmetry
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   C3
# ...                                                   ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   C3
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   C3
#
# protocol                                                                 \
# measure
# metric                               component_2_c_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                                     \
# measure
# metric                               component_2_max_radius
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210              53.564332
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              54.497854
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213              54.096864
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215              54.256571
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191              48.047899
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140              51.189786
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145              51.421290
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149              51.410586
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151              50.019126
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203              54.628992
#
# protocol                                                                 \
# measure
# metric                               component_2_n_terminal_orientation
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                                  1
# ...                                                                 ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                                  1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                                  1
#
# protocol                                               \
# measure
# metric                               component_2_name
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191           4M1A_1
# ...                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151           4M1A_1
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203           4M1A_1
#
# protocol                                                             \
# measure
# metric                               component_2_number_of_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                            106
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                            106
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                            106
#
# protocol                                                                    \
# measure
# metric                               component_2_symmetry design_dimension
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   C3                0
# ...                                                   ...              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   C3                0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   C3                0
#
# protocol                                                         \
# measure
# metric                               interface_b_factor_per_res
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                       20.0
# ...                                                         ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                       20.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                       20.0
#
# protocol                                                                      \
# measure
# metric                               multiple_fragment_ratio nanohedra_score
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                3.666667       17.797829
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                3.555556       19.917511
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                4.000000       18.144322
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                3.777778       18.692283
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                2.363636       24.027251
# ...                                                      ...             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                3.777778       20.999764
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                3.500000       21.938419
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                3.500000       21.219092
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                4.222222       21.547762
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                4.222222       19.590534
#
# protocol                                                     \
# measure
# metric                               nanohedra_score_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210               5.939412
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211              10.124070
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213               8.033094
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215               9.506577
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191               8.484664
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140               6.802112
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145               6.056401
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149               5.879402
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151               7.644833
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203               9.909078
#
# protocol                                                                    \
# measure
# metric                               nanohedra_score_center_per_res_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                              0.989902
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                              1.124897
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                              1.004137
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                              1.056286
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                              0.771333
# ...                                                                    ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                              0.755790
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                              0.757050
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                              0.734925
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                              0.849426
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                              1.101009
#
# protocol                                                              \
# measure
# metric                               number_fragment_residues_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                               6
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                              11
# ...                                                              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                               8
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                               9
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                               9
#
# protocol                                                             \
# measure
# metric                               number_fragment_residues_total
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                             18
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                             19
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                             35
# ...                                                             ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                             31
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                             30
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                             30
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                             29
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                             19
#
# protocol                                                    \
# measure
# metric                               percent_fragment_coil
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                   0.0
# ...                                                    ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                   0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                   0.0
#
# protocol                                                     \
# measure
# metric                               percent_fragment_helix
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                    1.0
# ...                                                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                    1.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                    1.0
#
# protocol                                                      \
# measure
# metric                               percent_fragment_strand
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                     0.0
# ...                                                      ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                     0.0
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                     0.0
#
# protocol                                                               \
# measure
# metric                               percent_residues_fragment_center
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                         0.193548
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                         0.187500
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                         0.156863
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                         0.173077
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                         0.440000
# ...                                                               ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                         0.140625
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                         0.131148
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                         0.125000
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                         0.147541
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                         0.173077
#
# protocol                                                              \
# measure
# metric                               percent_residues_fragment_total
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                        0.580645
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                        0.395833
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                        0.372549
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                        0.365385
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                        1.400000
# ...                                                              ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                        0.484375
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                        0.491803
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                        0.468750
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                        0.475410
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                        0.365385
#
# protocol                                                       \
# measure
# metric                               total_interface_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                       31
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                       48
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                       51
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                       52
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                       25
# ...                                                       ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                       64
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                       61
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                       64
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                       61
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                       52
#
# protocol                                                                       \
# measure
# metric                               number_fragments nanohedra_score_per_res
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210               11                0.988768
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211               16                1.048290
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213               16                0.954964
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215               17                0.983804
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191               13                0.686493
# ...                                               ...                     ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140               17                0.677412
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145               14                0.731281
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149               14                0.707303
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151               19                0.743026
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203               19                1.031081
#
# protocol
# measure
# metric                               non_fragment_residues
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_210                    25
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_211                    39
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_213                    43
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_215                    43
# 4mi2_4m1a-DEGEN_1_1-ROT_34_23-tx_191                    14
# ...                                                    ...
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_140                    55
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_145                    53
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_149                    56
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_151                    52
# 4mi2_4m1a-DEGEN_1_1-ROT_34_21-tx_203                    43
#
# [493874 rows x 29 columns]

# %%
df_descriptors = return_df_feature_descriptors(df)

# %%
df_descriptors
# Out:
#                                                        descriptors             \
#                                                               mean        std
# protocol measure metric
# pose     dock    component_1_c_terminal_orientation       0.294824   0.955552
#                  component_1_max_radius                  75.244177  17.118494
#                  component_1_n_terminal_orientation       0.563127   0.826371
#                  component_1_number_of_residues         183.759556  71.099310
#                  component_2_c_terminal_orientation       0.191960   0.981404
#                  component_2_max_radius                  75.456900  18.081794
#                  component_2_n_terminal_orientation       0.258924   0.965899
#                  component_2_number_of_residues         197.435763  77.341921
#                  design_dimension                         0.000000   0.000000
#                  interface_b_factor_per_res              20.000000   0.000000
#                  multiple_fragment_ratio                  3.524184   1.063585
#                  nanohedra_score                         21.694203   5.098653
#                  nanohedra_score_center                   8.460259   3.026140
#                  nanohedra_score_center_per_res_center    0.932243   0.139427
#                  number_fragment_residues_center          9.155696   3.148872
#                  number_fragment_residues_total          24.922063   7.210454
#                  percent_fragment_coil                    0.005649   0.023693
#                  percent_fragment_helix                   0.992493   0.027880
#                  percent_fragment_strand                  0.001858   0.014235
#                  percent_residues_fragment_center         0.337102   0.151532
#                  percent_residues_fragment_total          0.929882   0.418000
#                  total_interface_residues                31.314078  13.971467
#                  number_fragments                        16.340611   7.869852
#                  nanohedra_score_per_res                  0.891676   0.133030
#                  non_fragment_residues                   22.158383  13.100828
#
#                                                                                \
#                                                               min         max
# protocol measure metric
# pose     dock    component_1_c_terminal_orientation     -1.000000    1.000000
#                  component_1_max_radius                 39.685598  200.481232
#                  component_1_n_terminal_orientation     -1.000000    1.000000
#                  component_1_number_of_residues         33.000000  366.000000
#                  component_2_c_terminal_orientation     -1.000000    1.000000
#                  component_2_max_radius                 39.780388  206.341153
#                  component_2_n_terminal_orientation     -1.000000    1.000000
#                  component_2_number_of_residues         33.000000  384.000000
#                  design_dimension                        0.000000    0.000000
#                  interface_b_factor_per_res             20.000000   20.000000
#                  multiple_fragment_ratio                 1.000000    8.666667
#                  nanohedra_score                         9.408189   61.815956
#                  nanohedra_score_center                  2.173510   33.925110
#                  nanohedra_score_center_per_res_center   0.433220    1.811962
#                  number_fragment_residues_center         3.000000   34.000000
#                  number_fragment_residues_total         11.000000   83.000000
#                  percent_fragment_coil                   0.000000    0.857143
#                  percent_fragment_helix                  0.142857    1.000000
#                  percent_fragment_strand                 0.000000    0.500000
#                  percent_residues_fragment_center        0.035398    2.500000
#                  percent_residues_fragment_total         0.123894    8.500000
#                  total_interface_residues                2.000000  140.000000
#                  number_fragments                        2.000000   78.000000
#                  nanohedra_score_per_res                 0.435397    1.674070
#                  non_fragment_residues                  -7.000000  131.000000
#
#
#                                                              range
# protocol measure metric
# pose     dock    component_1_c_terminal_orientation       2.000000
#                  component_1_max_radius                 160.795634
#                  component_1_n_terminal_orientation       2.000000
#                  component_1_number_of_residues         333.000000
#                  component_2_c_terminal_orientation       2.000000
#                  component_2_max_radius                 166.560765
#                  component_2_n_terminal_orientation       2.000000
#                  component_2_number_of_residues         351.000000
#                  design_dimension                         0.000000
#                  interface_b_factor_per_res               0.000000
#                  multiple_fragment_ratio                  7.666667
#                  nanohedra_score                         52.407766
#                  nanohedra_score_center                  31.751601
#                  nanohedra_score_center_per_res_center    1.378742
#                  number_fragment_residues_center         31.000000
#                  number_fragment_residues_total          72.000000
#                  percent_fragment_coil                    0.857143
#                  percent_fragment_helix                   0.857143
#                  percent_fragment_strand                  0.500000
#                  percent_residues_fragment_center         2.464602
#                  percent_residues_fragment_total          8.376106
#                  total_interface_residues               138.000000
#                  number_fragments                        76.000000
#                  nanohedra_score_per_res                  1.238674
#                  non_fragment_residues                  138.000000

# %%
unique_protocols = df.columns.get_level_values('protocol').unique().to_list()
unique_protocols.remove('pose')

# %%
pose_df = df.loc[:, idx['pose',[mean, 'dock', 'seq_design'], :]]
pose_df = pose_df.droplevel(1, axis=1)  # .droplevel(0, axis=1)

# %%
# display(pose_df)
pose_df.loc['2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_131', :]
# Out:
# protocol  metric
# pose      component_1_c_terminal_orientation               1
#           component_1_max_radius                   51.669205
#           component_1_n_terminal_orientation              -1
#           component_1_name                            2PD2_1
#           component_1_number_of_residues                 108
#           component_1_symmetry                            C3
#           component_2_c_terminal_orientation               1
#           component_2_max_radius                   80.760612
#           component_2_n_terminal_orientation              -1
#           component_2_name                            4N72_1
#           component_2_number_of_residues                 245
#           component_2_symmetry                            C3
#           design_dimension                                 0
#           interface_b_factor_per_res                    20.0
#           multiple_fragment_ratio                       5.75
#           nanohedra_score                           44.64217
#           nanohedra_score_center                   24.120111
#           nanohedra_score_center_per_res_center     1.005005
#           number_fragment_residues_center                 24
#           number_fragment_residues_total                  47
#           percent_fragment_coil                          0.0
#           percent_fragment_helix                         1.0
#           percent_fragment_strand                        0.0
#           percent_residues_fragment_center           0.45283
#           percent_residues_fragment_total           0.886792
#           total_interface_residues                        53
#           number_fragments                                69
#           nanohedra_score_per_res                   0.949833
#           non_fragment_residues                           29
# Name: 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_131, dtype: object

# %% [markdown]
# ## Filter on metrics in the dataframe
# These metrics were pulled from Janin et al. 2008 as the set of crystal interface identifiers.
# You can define other identifiers in similar {key: value} pairs

# %%
crystal_means = {'int_area_total': 570, 'shape_complementarity': 0.63, 'number_hbonds': 5}
# Each of these produces the highest 10% scoring for the individual metrics
top_10_percent = {'total_interface_residues': 50,  # 35-176002 35-70 in Bale work with 12 A distance...
               'nanohedra_score_center': 12.5,  # 13-38904, 15-15018
               'multiple_fragment_ratio': 5,  # 49410 , lower (3.52) missed beneficial additive secondary structure
               'number_fragments': 28}  # 25-74423, 20-148471
other_means = {'total_interface_residues': 35,  # -176002 35-70 in Bale work with 12 A distance...
               'nanohedra_score_center': 15,  # -15018
               'multiple_fragment_ratio': 5,  # 49410 , lower (3.52) missed beneficial additive secondary structure
               'number_fragments': 20}  #-148471
homo_bio_means = {'total_interface_residues': 81,  # 2099
                  'nanohedra_score_center': 14.28,  # 21310
                  'multiple_fragment_ratio': 2.41,  # 413620
                  'number_fragments': 21.22}  # 114185
sheet_means = {'total_interface_residues': 35,
#                'nanohedra_score_central': 15,
               'percent_fragment_strand': 0.2}  # this gives 222 designs

# %% [markdown]
# Modify 'design_filters' variable to set your filters of choice

# %%
design_filters = other_means
# design_selection_file = '210331_T33DockingMetricsPose.ids'

# design_filters = homo_bio_means

# design_filters = top_10_percent
design_selection_file = '210331_T33Top10percentDockingPoseMetric.ids'

# %%
print('Starting designs = %d' % len(pose_df))
filtered_indices = {}
for metric in design_filters:
    filtered_indices[metric] = set(pose_df[pose_df.droplevel(0, axis=1)[metric] >= design_filters[metric]].index.to_list())
    print('Number of designs passing %s = %d' % (metric, len(filtered_indices[metric])))
# Out:
# Starting designs = 493874
# Number of designs passing total_interface_residues = 176002
# Number of designs passing nanohedra_score_center = 15018
# Number of designs passing multiple_fragment_ratio = 49410
# Number of designs passing number_fragments = 148471

# %%
final_indices = index_intersection(filtered_indices)
print('Final number of designs passing all metrics is %d' % len(final_indices))
# Out:
# Final number of designs passing all metrics is 1431

# %%
filtered_df = df.loc[final_indices, :].droplevel(0, axis=1).droplevel(0, axis=1).sort_values('nanohedra_score_center')

# %%
display(filtered_df)
# Out:
# metric                                component_1_c_terminal_orientation  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                                   1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                   -1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                    1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                      1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                   -1
# ...                                                                  ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                                   1
#
# metric                                component_1_max_radius  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192               83.157840
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                80.656150
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                53.527106
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                  96.861910
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                58.471713
# ...                                                      ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208               52.082789
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249               52.179511
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161               52.158402
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144               52.188222
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192               52.328006
#
# metric                                component_1_n_terminal_orientation  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                                  -1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                    1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                    1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                      1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                   -1
# ...                                                                  ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                                  -1
#
# metric                               component_1_name  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192           3TCR_1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168            6SLB_1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77            3TCR_1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65              3Q98_1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37            3L7Q_1
# ...                                               ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208           2PD2_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249           2PD2_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161           2PD2_1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144           2PD2_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192           2PD2_1
#
# metric                                component_1_number_of_residues  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                             158
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                              254
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                              158
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                366
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                              124
# ...                                                              ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                             108
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                             108
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                             108
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                             108
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                             108
#
# metric                               component_1_symmetry  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                   C3
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                    C3
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                    C3
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                      C3
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                    C3
# ...                                                   ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                   C3
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                   C3
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                   C3
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                   C3
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                   C3
#
# metric                                component_2_c_terminal_orientation  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                                  -1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                    1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                   -1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                      1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                    1
# ...                                                                  ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                                   1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                                   1
#
# metric                                component_2_max_radius  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192               75.336960
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                78.062389
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                79.389973
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                  53.200204
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                78.282484
# ...                                                      ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208               81.329946
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249               81.110639
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161               80.921203
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144               80.439437
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192               81.019118
#
# metric                                component_2_n_terminal_orientation  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                                   1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                    1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                   -1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                      1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                   -1
# ...                                                                  ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                                  -1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                                  -1
#
# metric                               component_2_name  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192           4GLJ_1
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168            3QV0_1
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77            2I9D_1
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65              3L7Q_1
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37            2I9D_1
# ...                                               ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208           4N72_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249           4N72_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161           4N72_1
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144           4N72_1
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192           4N72_1
#
# metric                                component_2_number_of_residues  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                             287
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                              179
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                              186
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                124
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                              186
# ...                                                              ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                             245
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                             245
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                             245
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                             245
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                             245
#
# metric                               component_2_symmetry  design_dimension  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                   C3                 0
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                    C3                 0
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                    C3                 0
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                      C3                 0
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                    C3                 0
# ...                                                   ...               ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                   C3                 0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                   C3                 0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                   C3                 0
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                   C3                 0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                   C3                 0
#
# metric                                interface_b_factor_per_res  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                        20.0
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                         20.0
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                         20.0
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                           20.0
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                         20.0
# ...                                                          ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                        20.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                        20.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                        20.0
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                        20.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                        20.0
#
# metric                                multiple_fragment_ratio  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                 6.166667
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                  5.000000
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                  5.272727
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                    5.000000
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                  5.666667
# ...                                                       ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                 5.583333
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                 5.739130
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                 5.478261
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                 5.200000
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                 5.391304
#
# metric                                nanohedra_score  nanohedra_score_center  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192        26.898109               12.502078
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168         33.384214               12.512304
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77         24.642473               12.524364
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65           33.385848               12.533732
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37         30.056196               12.535493
# ...                                               ...                     ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208        46.976863               24.723815
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249        49.670986               25.358188
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161        50.141890               25.622209
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144        46.078609               25.714162
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192        50.677060               26.272823
#
# metric                                nanohedra_score_center_per_res_center  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                               1.041840
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                1.042692
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                1.138579
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                  0.895267
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                1.044624
# ...                                                                     ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                               1.030159
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                               1.102530
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                               1.114009
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                               1.028566
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                               1.142297
#
# metric                                number_fragment_residues_center  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                               12
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                                12
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                                11
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                  14
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                                12
# ...                                                               ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                               24
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                               23
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                               23
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                               25
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                               23
#
# metric                                number_fragment_residues_total  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                              26
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                               32
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                               24
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                                 38
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                               31
# ...                                                              ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                              47
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                              47
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                              47
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                              47
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                              47
#
# metric                                percent_fragment_coil  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                    0.0
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                     0.0
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                     0.0
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                       0.0
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                     0.0
# ...                                                     ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                    0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                    0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                    0.0
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                    0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                    0.0
#
# metric                                percent_fragment_helix  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                     1.0
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                      1.0
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                      1.0
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                        1.0
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                      1.0
# ...                                                      ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                     1.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                     1.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                     1.0
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                     1.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                     1.0
#
# metric                                percent_fragment_strand  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                      0.0
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                       0.0
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                       0.0
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                         0.0
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                       0.0
# ...                                                       ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                      0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                      0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                      0.0
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                      0.0
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                      0.0
#
# metric                                percent_residues_fragment_center  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                          0.235294
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                           0.210526
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                           0.169231
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                             0.280000
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                           0.214286
# ...                                                                ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                          0.480000
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                          0.442308
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                          0.442308
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                          0.462963
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                          0.442308
#
# metric                                percent_residues_fragment_total  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                         0.509804
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                          0.561404
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                          0.369231
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                            0.760000
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                          0.553571
# ...                                                               ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                         0.940000
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                         0.903846
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                         0.903846
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                         0.870370
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                         0.903846
#
# metric                                total_interface_residues  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                        51
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                         57
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                         65
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                           50
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                         56
# ...                                                        ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                        50
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                        52
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                        52
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                        54
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                        52
#
# metric                                number_fragments  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                37
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                 30
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                 29
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                   35
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                 34
# ...                                                ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                67
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                66
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                63
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                65
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                62
#
# metric                                nanohedra_score_per_res  \
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                 1.034543
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                  1.043257
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                  1.026770
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                    0.878575
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                  0.969555
# ...                                                       ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                 0.999508
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                 1.056829
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                 1.066849
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                 0.980396
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                 1.078235
#
# metric                                non_fragment_residues
# 3tcr_4glf-DEGEN_1_1-ROT_40_12-tx_192                     39
# 3hrx_3qv0-DEGEN_1_1-ROT_22_8-tx_168                      45
# 3tcr_2i9d-DEGEN_1_1-ROT_26_21-tx_77                      54
# 3q98_3l7q-DEGEN_1_1-ROT_1_4-tx_65                        36
# 3l7q_2i9d-DEGEN_1_1-ROT_37_35-tx_37                      44
# ...                                                     ...
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_208                     26
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_249                     29
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_161                     29
# 2pd2_4n72-DEGEN_1_1-ROT_20_37-tx_144                     29
# 2pd2_4n72-DEGEN_1_1-ROT_21_36-tx_192                     29
#
# [851 rows x 29 columns]

# %%
with open(design_selection_file, 'w') as f:
    f.write('\n'.join(final_indices))
print('Wrote file to %s' % design_selection_file)
# Out:
# Wrote file to 210331_T33Top10percentDockingPoseMetric.ids

# %%
giant_cluster = ['2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_277', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_236', 
                 '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_212', '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_260', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_240', '2vky_4ogg-DEGEN_1_2-ROT_21_24-tx_211', 
                 '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_276', '2vky_4ogg-DEGEN_1_2-ROT_19_25-tx_223', 
                 '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_262', '2vky_4ogg-DEGEN_1_2-ROT_19_25-tx_246', 
                 '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_255', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_262', 
                 '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_267', '2vky_4ogg-DEGEN_1_2-ROT_11_27-tx_282', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_305', '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_229', 
                 '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_312', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_244', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_241', '2vky_4ogg-DEGEN_1_2-ROT_11_27-tx_305', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_258', '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_293', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_306', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_247', 
                 '2vky_4ogg-DEGEN_1_2-ROT_19_25-tx_216', '2vky_4ogg-DEGEN_1_2-ROT_16_25-tx_270', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_283', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_237', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_259', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_231', 
                 '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_252', '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_214', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_321', '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_323', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_248', '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_215', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_287', '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_260', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_234', '2vky_4ogg-DEGEN_1_2-ROT_21_24-tx_221', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_246', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_250', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_317', '2vky_4ogg-DEGEN_1_2-ROT_13_26-tx_274', 
                 '2vky_4ogg-DEGEN_1_2-ROT_19_25-tx_276', '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_270', 
                 '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_261', '2vky_4ogg-DEGEN_1_2-ROT_16_25-tx_260', 
                 '2vky_4ogg-DEGEN_1_2-ROT_11_27-tx_266', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_279', 
                 '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_309', '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_227', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_273', '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_285', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_227', '2vky_4ogg-DEGEN_1_2-ROT_21_24-tx_233', 
                 '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_217', '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_286', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_254', '2vky_4ogg-DEGEN_1_2-ROT_12_27-tx_282', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_239', '2vky_4ogg-DEGEN_1_2-ROT_11_27-tx_281', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_262', '2vky_4ogg-DEGEN_1_2-ROT_21_24-tx_216', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_327', '2vky_4ogg-DEGEN_1_2-ROT_18_25-tx_238', 
                 '2vky_4ogg-DEGEN_1_2-ROT_14_26-tx_257', '2vky_4ogg-DEGEN_1_2-ROT_15_26-tx_247', 
                 '2vky_4ogg-DEGEN_1_2-ROT_13_26-tx_268', '2vky_4ogg-DEGEN_1_2-ROT_20_24-tx_227', 
                 '2vky_4ogg-DEGEN_1_2-ROT_17_25-tx_220']

# %%
giant_cluster_df = filtered_df.loc[giant_cluster, :].sort_values('nanohedra_score')

# %%
num_obs_df = filtered_df.loc[:, idx[:, ['stats'], ['observations']]].droplevel(1, axis=1)

# %%
stats_df = filtered_df.loc[:, idx[:, ['stats'], ['observations']]].droplevel(1, axis=1)

# %% [markdown]
# ### Looking into the contributions of different metrics to the filtered poses

# %%
filtered_pose_df = filtered_df.loc[:, idx['pose', df.columns.get_level_values(1) != std, :]].droplevel(1, axis=1).droplevel(0, axis=1)
filtered_pose_df.drop('symmetry', axis=1, inplace=True, errors='ignore')

# %%
display(filtered_pose_df)
# Out:
# metric                                average_fragment_z_score  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                    0.876481
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                    0.736054
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                    0.777590
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                   0.655106
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                   0.792879
# ...                                                        ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                    0.743833
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                    0.792705
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                   0.739884
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                    0.927689
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                  0.659982
#
# metric                                interface_b_factor_per_res  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                          20.0
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                          20.0
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                          20.0
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                         20.0
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                         20.0
# ...                                                          ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                          20.0
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                          20.0
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                         20.0
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                          20.0
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                        20.0
#
# metric                                nanohedra_score  observations  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339           4.580459            58
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946           4.903429            56
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296           1.286024            56
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935          6.644818            62
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123          7.940886            62
# ...                                               ...           ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467           8.487259            55
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295           5.103849            60
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855          5.591035            63
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357           5.800009            66
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211         7.057863            63
#
# metric                                percent_fragment  unique_fragments  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339            0.640000                 4
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946            0.341463                 3
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296            0.148148                 1
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935           0.619048                 4
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123           0.466667                 6
# ...                                                ...               ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467            0.857143                 6
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295            0.419355                 4
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855           0.823529                 4
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357            0.656250                 4
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211          0.406250                 4
#
# metric                                buns_heavy_total  buns_hpol_total  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339            0.035714         0.000000
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946            3.166667         2.425926
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296            0.833333         0.629630
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935           0.466667         0.416667
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123           1.850000         1.300000
# ...                                                ...              ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467            0.188679         0.226415
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295            2.103448         0.413793
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855           1.426230         0.278689
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357            0.281250         0.218750
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211          1.475410         0.737705
#
# metric                                buns_per_ang  buns_total  contact_count  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339        0.000027    0.035714     121.750000
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946        0.002916    5.592593     148.259259
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296        0.000989    1.462963     131.481481
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935       0.000765    0.883333      87.350000
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123       0.001617    3.150000     107.783333
# ...                                            ...         ...            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467        0.000301    0.415094     151.641509
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295        0.001612    2.517241     170.672414
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855       0.001158    1.704918      59.688525
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357        0.000290    0.500000     110.031250
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211      0.001122    2.213115     104.557377
#
# metric                                     core  cst_weight  fsp_energy  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339     9.446429    4.365540   -0.989643
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946    21.129630   15.547992   -0.889815
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296    15.111111   17.994370   -0.399815
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935   10.433333    5.247335   -0.538667
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123   16.966667   11.987110   -0.574167
# ...                                         ...         ...         ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467    12.339623    6.195595   -0.806038
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295    15.637931   19.687336   -0.218276
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855   11.852459    7.448518   -0.523934
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357    15.765625   11.859366   -0.827031
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211  15.967213   13.230722   -0.461803
#
# metric                                int_area_hydrophobic  int_area_polar  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339              957.825933      335.614418
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946             1272.967699      647.842902
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296             1061.733718      414.737934
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935             822.894475      344.370881
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123            1422.636353      509.460147
# ...                                                    ...             ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467              968.676726      395.191684
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295              978.667723      581.879601
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855            1007.411287      451.605992
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357             1154.444924      535.542913
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211           1203.919433      755.827018
#
# metric                                int_area_total  int_composition_diff  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339       1293.440356              0.551926
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946       1920.810617              0.742960
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296       1476.471646              0.694079
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935      1167.265368              0.666300
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123      1932.096503              0.576559
# ...                                              ...                   ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467       1363.868413              0.617426
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295       1560.547325              0.816615
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855      1459.017286              0.521808
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357       1689.987835              0.671181
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211     1959.746448              0.684792
#
# metric                                int_connectivity_A  int_connectivity_B  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339             17.716518           12.714744
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946             16.739031           17.886632
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296             17.759925           11.775672
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935            15.296397           15.760385
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123            15.147038           14.532133
# ...                                                  ...                 ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467             16.115100           14.224463
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295             18.970307           18.822965
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855            12.335935           14.879391
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357             17.424788           14.955693
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211           16.205218           18.510225
#
# metric                                int_energy_context_oligomer_A  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                       -16.592692
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                       -25.744404
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                        -7.612270
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                      -10.821042
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                       -4.577094
# ...                                                             ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                       -12.414683
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                       -31.140944
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                      -30.536634
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                       -30.489849
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                     -20.267723
#
# metric                                int_energy_context_oligomer_B  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                       -11.732157
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                       -22.943402
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                        -7.164742
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                       -9.791965
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                      -16.247031
# ...                                                             ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                        -8.396045
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                       -19.882483
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                       -5.232160
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                       -16.498158
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                     -18.596928
#
# metric                                int_energy_res_summary_complex  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                        -81.889466
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                       -113.532538
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                        -53.200796
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                       -65.747328
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                       -71.836188
# ...                                                              ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                        -72.994688
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                       -111.397795
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                       -82.072372
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                       -104.834117
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                      -87.486718
#
# metric                                int_energy_res_summary_delta  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                      -35.287287
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                      -36.177101
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                      -24.049705
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                     -30.367074
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                     -27.621929
# ...                                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                      -36.505457
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                      -35.344533
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                     -22.985596
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                      -33.376966
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                    -27.288868
#
# metric                                int_energy_res_summary_oligomer  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                         -46.602180
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                         -77.355437
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                         -29.151091
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                        -35.380254
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                        -44.214258
# ...                                                               ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                         -36.489230
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                         -76.053262
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                        -59.086775
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                         -71.457150
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                       -60.197850
#
# metric                                int_energy_res_summary_oligomer_A  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                           -26.101119
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                           -40.978062
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                           -14.970323
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                          -18.915002
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                          -13.548474
# ...                                                                 ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                           -20.424532
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                           -46.052963
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                          -48.755279
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                           -42.798933
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                         -32.554760
#
# metric                                int_energy_res_summary_oligomer_B  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                           -20.501060
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                           -36.377375
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                           -14.180768
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                          -16.465252
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                          -30.665784
# ...                                                                 ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                           -16.064698
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                           -30.000299
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                          -10.331496
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                           -28.658218
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                         -27.643090
#
# metric                                int_separation  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339          0.388593
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946          0.535562
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296          0.599614
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935         0.480186
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123         0.484110
# ...                                              ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467          0.433643
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295          0.528196
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855         0.467416
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357          0.391492
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211        0.557880
#
# metric                                interaction_energy_complex  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                    -34.379849
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                    -25.201272
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                    -26.691111
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                   -27.202637
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                   -21.859303
# ...                                                          ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                    -33.809916
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                    -39.280671
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                   -20.921401
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                    -30.012823
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                  -23.303546
#
# metric                                number_hbonds  observed_combined  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339         5.267857           0.998571
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946         7.981481           0.984815
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296         5.481481           0.984463
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935        5.333333           1.000000
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123        5.033333           0.997750
# ...                                             ...                ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467         7.396226           0.995264
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295         6.655172           0.983776
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855        5.442623           0.974721
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357         7.500000           0.988187
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211      10.590164           0.992623
#
# metric                                observed_evolution  observed_fragment  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339              0.998571           0.785714
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946              0.988519           0.875000
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296              0.985056           0.953704
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935             1.000000           0.993333
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123             0.997300           0.747917
# ...                                                  ...                ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467              0.999208           0.807698
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295              0.985466           0.894879
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855             0.994721           0.583459
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357              0.982703           0.717047
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211            0.984426           0.875000
#
# metric                                percent_core  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339        0.377857
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946        0.515357
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296        0.559671
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935       0.496825
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123       0.565556
# ...                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467        0.587601
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295        0.504449
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855       0.697203
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357        0.492676
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211      0.498975
#
# metric                                percent_int_area_hydrophobic  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                        0.740636
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                        0.662064
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                        0.719911
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                       0.704942
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                       0.736809
# ...                                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                        0.709522
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                        0.627454
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                       0.691421
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                        0.683140
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                      0.614510
#
# metric                                percent_int_area_polar  percent_rim  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                  0.259364     0.501429
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                  0.337936     0.287715
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                  0.280089     0.371056
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                 0.295058     0.402381
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                 0.263191     0.256111
# ...                                                      ...          ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                  0.290478     0.381851
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                  0.372546     0.300890
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                 0.308579     0.324012
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                  0.316860     0.460938
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                0.385490     0.381148
#
# metric                                percent_support         ref        rim  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339           0.081429  204.087237  12.535714
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946           0.252936  213.460259  11.796296
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296           0.168724  202.896352  10.018519
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935          0.148413  224.973297   8.450000
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123          0.233889  144.379521   7.683333
# ...                                               ...         ...        ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467           0.168014  205.613195   8.018868
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295           0.392102  253.799642   9.327586
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855          0.264224   39.848212   5.508197
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357           0.120605  208.385745  14.750000
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211         0.286373  224.168386  12.196721
#
# metric                                    rmsd  shape_complementarity  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339    0.062525               0.798538
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946    0.367619               0.673368
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296    0.102061               0.630098
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935   0.083173               0.705811
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123   0.129299               0.694221
# ...                                        ...                    ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467    0.030393               0.756074
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295    0.340667               0.669385
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855   0.501452               0.735090
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357    0.132586               0.775912
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211  0.204604               0.685884
#
# metric                                solvation_energy    support  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339            0.907438   2.035714
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946           10.975829  10.370370
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296           -2.641406   4.555556
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935           3.164437   3.116667
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123           5.762627   7.016667
# ...                                                ...        ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467            2.695542   3.528302
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295           -3.936138  12.155172
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855           2.064195   4.491803
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357            3.364143   3.859375
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211          3.985322   9.163934
#
# metric                                total_interface_residues  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                        25.0
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                        41.0
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                        27.0
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                       21.0
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                       30.0
# ...                                                        ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                        21.0
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                        31.0
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                       17.0
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                        32.0
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                      32.0
#
# metric                                divergence_combined_per_res  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                          0.587
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                          0.541
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                          0.580
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                         0.649
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                         0.484
# ...                                                           ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                          0.524
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                          0.451
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                         0.436
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                          0.526
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                        0.540
#
# metric                                divergence_evolution_per_res  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                           0.609
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                           0.559
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                           0.580
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                          0.664
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                          0.490
# ...                                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                           0.555
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                           0.471
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                          0.469
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                           0.538
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                         0.551
#
# metric                                divergence_fragment_per_res  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                          0.747
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                          0.499
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                          0.488
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                         0.590
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                         0.622
# ...                                                           ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                          0.636
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                          0.587
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                         0.687
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                          0.641
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                        0.666
#
# metric                                divergence_interface_per_res  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                           0.792
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                           0.694
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                           0.712
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                          0.784
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                          0.705
# ...                                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                           0.672
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                           0.725
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                          0.687
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                           0.745
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                         0.745
#
# metric                                protocol_energy_distance_sum  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                       16.415393
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                        6.673705
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                       11.890098
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                       5.410405
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                       7.468796
# ...                                                            ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                        8.970561
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                        8.236956
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                       0.722363
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                        8.798484
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                      8.068720
#
# metric                                protocol_seq_distance_sum  \
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                    22.188907
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                    13.142350
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                    10.158871
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                   10.942026
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                    6.979281
# ...                                                         ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                    10.108777
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                    10.450041
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                   17.982529
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                    15.649974
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                  14.762139
#
# metric                                protocol_similarity_sum
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_339                   1.355250
# 4f47_4ast-DEGEN_1_1-ROT_5_1-tx_946                   2.344125
# 4f47_4grd-DEGEN_1_1-ROT_8_1-tx_296                   2.161375
# 2q0t_1bkh-DEGEN_1_1-ROT_16_1-tx_935                  1.623000
# 1o5j_4grd-DEGEN_1_1-ROT_39_1-tx_123                  1.765500
# ...                                                       ...
# 1zoi_4ast-DEGEN_1_2-ROT_2_1-tx_467                   2.178125
# 3zo8_4j3z-DEGEN_1_1-ROT_8_1-tx_295                   1.927125
# 3wfv_2ap6-DEGEN_1_1-ROT_13_1-tx_855                  1.647500
# 4f47_4grd-DEGEN_1_1-ROT_9_1-tx_357                   2.129375
# 2i9d_3aff-DEGEN_1_1-ROT_15_1-tx_1211                 2.065000
#
# [198 rows x 52 columns]

# %%
filtered_pose_descriptor_df = return_df_feature_descriptors(filtered_pose_df)

# %%
display(pose_sum_stats_df)

# %% [markdown]
# ## Get all protocol mean/stats metrics
# This will only work for designs after sequence design has been performed

# %%
# full_protocol_df = df.loc[:, idx[df.columns.get_level_values(0) != 'pose', 
#                                  [df.columns.get_level_values(1) == mean, df.columns.get_level_values(1) == 'stats'],
#                                  :]].droplevel(1, axis=1)
mean_protocol_df = df.loc[:, idx[df.columns.get_level_values(0) != 'pose', df.columns.get_level_values(1) == mean, :]].droplevel(1, axis=1)
stats_protocol_df = df.loc[:, idx[df.columns.get_level_values(0) != 'pose', df.columns.get_level_values(1) == 'stats', :]].droplevel(1, axis=1)
design_protocols_df = pd.merge(mean_protocol_df, stats_protocol_df, left_index=True, right_index=True)

# %%
# full_protocol_df = df.loc[:, idx[df.columns.get_level_values(0) == 'pose', df.columns.get_level_values(1) != 'stdev', :]].droplevel(1, axis=1)  # gets dock as well

# %%
limited_protocols = list(set(df.columns.get_level_values(0).to_list()) - {'pose', 'consensus'})

# %%
mean_no_constraint_df = df.loc[:, idx[df.columns.get_level_values(0) == 'no_constraint', df.columns.get_level_values(1) == mean, :]].droplevel(1, axis=1)
stats_no_constraint_df = df.loc[:, idx[df.columns.get_level_values(0) == 'no_constraint', df.columns.get_level_values(1) == 'stats', :]].droplevel(1, axis=1)
no_constraint_protocol_df = pd.merge(mean_no_constraint_df, stats_no_constraint_df, left_index=True, right_index=True)

# %%
# protocol_df = mean_protocol_df  # protocols only looking at mean
# protocol_df = stats_protocol_df  # protocols only looking at stats

# %% [markdown]
# # Protocol Switch point for checking graphs below

# %%
# All df have two column levels
protocol_df = pose_df  # all pose metrics, no sd
# protocol_df = design_protocols_df  # all pose, protocol metrics, no sd
# protocol_df = xtal_pose_df  # poses matching crystalline parameters, no sd
# protocol_df = xtal_pose_filtered_df  # same as above, protocol similarity metric appended
# protocol_df = limited_protocol_df  # subset of desired protocols looking at mean and only limit_to_profile

# %%
display(protocol_df.corr(method='spearman'))
# Out:
# protocol                                                       pose  \
# metric                                     average_fragment_z_score
# protocol metric
# pose     average_fragment_z_score                          1.000000
#          interface_b_factor_per_res                             NaN
#          nanohedra_score                                  -0.491266
#          observations                                      0.011529
#          percent_fragment                                 -0.152573
#          unique_fragments                                 -0.212802
#          buns_heavy_total                                 -0.002064
#          buns_hpol_total                                   0.034060
#          buns_per_ang                                      0.024917
#          buns_total                                        0.008986
#          contact_count                                    -0.063317
#          core                                             -0.056268
#          cst_weight                                        0.035068
#          fsp_energy                                        0.179225
#          int_area_hydrophobic                             -0.089048
#          int_area_polar                                    0.039031
#          int_area_total                                   -0.050864
#          int_composition_diff                             -0.019228
#          int_connectivity_A                                0.059585
#          int_connectivity_B                                0.017138
#          int_energy_context_oligomer_A                    -0.004455
#          int_energy_context_oligomer_B                     0.063021
#          int_energy_res_summary_complex                    0.061745
#          int_energy_res_summary_delta                      0.133014
#          int_energy_res_summary_oligomer                   0.047456
#          int_energy_res_summary_oligomer_A                 0.000845
#          int_energy_res_summary_oligomer_B                 0.083381
#          int_separation                                    0.045679
#          interaction_energy_complex                        0.136464
#          number_hbonds                                     0.033006
#          observed_combined                                -0.029658
#          observed_evolution                                0.024677
#          observed_fragment                                -0.113935
#          percent_core                                     -0.057415
#          percent_int_area_hydrophobic                     -0.176271
#          percent_int_area_polar                            0.176271
#          percent_rim                                       0.019507
#          percent_support                                  -0.019091
#          ref                                              -0.045287
#          rim                                               0.003733
#          rmsd                                              0.002786
#          shape_complementarity                            -0.089521
#          solvation_energy                                  0.050636
#          support                                          -0.010489
#          total_interface_residues                         -0.013532
#          divergence_combined_per_res                      -0.014796
#          divergence_evolution_per_res                     -0.045784
#          divergence_fragment_per_res                       0.041683
#          divergence_interface_per_res                      0.046756
#          protocol_energy_distance_sum                      0.003924
#          protocol_seq_distance_sum                        -0.009299
#          protocol_similarity_sum                           0.069604
#
# protocol                                                               \
# metric                                     interface_b_factor_per_res
# protocol metric
# pose     average_fragment_z_score                                 NaN
#          interface_b_factor_per_res                               NaN
#          nanohedra_score                                          NaN
#          observations                                             NaN
#          percent_fragment                                         NaN
#          unique_fragments                                         NaN
#          buns_heavy_total                                         NaN
#          buns_hpol_total                                          NaN
#          buns_per_ang                                             NaN
#          buns_total                                               NaN
#          contact_count                                            NaN
#          core                                                     NaN
#          cst_weight                                               NaN
#          fsp_energy                                               NaN
#          int_area_hydrophobic                                     NaN
#          int_area_polar                                           NaN
#          int_area_total                                           NaN
#          int_composition_diff                                     NaN
#          int_connectivity_A                                       NaN
#          int_connectivity_B                                       NaN
#          int_energy_context_oligomer_A                            NaN
#          int_energy_context_oligomer_B                            NaN
#          int_energy_res_summary_complex                           NaN
#          int_energy_res_summary_delta                             NaN
#          int_energy_res_summary_oligomer                          NaN
#          int_energy_res_summary_oligomer_A                        NaN
#          int_energy_res_summary_oligomer_B                        NaN
#          int_separation                                           NaN
#          interaction_energy_complex                               NaN
#          number_hbonds                                            NaN
#          observed_combined                                        NaN
#          observed_evolution                                       NaN
#          observed_fragment                                        NaN
#          percent_core                                             NaN
#          percent_int_area_hydrophobic                             NaN
#          percent_int_area_polar                                   NaN
#          percent_rim                                              NaN
#          percent_support                                          NaN
#          ref                                                      NaN
#          rim                                                      NaN
#          rmsd                                                     NaN
#          shape_complementarity                                    NaN
#          solvation_energy                                         NaN
#          support                                                  NaN
#          total_interface_residues                                 NaN
#          divergence_combined_per_res                              NaN
#          divergence_evolution_per_res                             NaN
#          divergence_fragment_per_res                              NaN
#          divergence_interface_per_res                             NaN
#          protocol_energy_distance_sum                             NaN
#          protocol_seq_distance_sum                                NaN
#          protocol_similarity_sum                                  NaN
#
# protocol                                                                 \
# metric                                     nanohedra_score observations
# protocol metric
# pose     average_fragment_z_score                -0.491266     0.011529
#          interface_b_factor_per_res                    NaN          NaN
#          nanohedra_score                          1.000000    -0.118977
#          observations                            -0.118977     1.000000
#          percent_fragment                         0.448053     0.095699
#          unique_fragments                         0.929539    -0.139045
#          buns_heavy_total                        -0.004487    -0.162751
#          buns_hpol_total                          0.024434    -0.156362
#          buns_per_ang                            -0.077606    -0.091690
#          buns_total                               0.003150    -0.162557
#          contact_count                            0.164404    -0.275943
#          core                                     0.182634    -0.228759
#          cst_weight                               0.060782    -0.195465
#          fsp_energy                              -0.530125     0.080850
#          int_area_hydrophobic                     0.235562    -0.211154
#          int_area_polar                           0.043322    -0.196700
#          int_area_total                           0.185185    -0.210792
#          int_composition_diff                     0.087734    -0.220982
#          int_connectivity_A                       0.016692     0.014670
#          int_connectivity_B                      -0.010549    -0.202223
#          int_energy_context_oligomer_A            0.024304     0.077511
#          int_energy_context_oligomer_B           -0.115777     0.231239
#          int_energy_res_summary_complex          -0.177197     0.237879
#          int_energy_res_summary_delta            -0.333761     0.233780
#          int_energy_res_summary_oligomer         -0.110355     0.212336
#          int_energy_res_summary_oligomer_A       -0.007408     0.105619
#          int_energy_res_summary_oligomer_B       -0.187425     0.244445
#          int_separation                          -0.157141     0.074638
#          interaction_energy_complex              -0.322230     0.211221
#          number_hbonds                            0.080821    -0.215261
#          observed_combined                       -0.026967    -0.058560
#          observed_evolution                       0.006484    -0.037999
#          observed_fragment                        0.287098    -0.017148
#          percent_core                             0.106359     0.010361
#          percent_int_area_hydrophobic             0.255845     0.020079
#          percent_int_area_polar                  -0.255845    -0.020079
#          percent_rim                             -0.027651     0.045457
#          percent_support                          0.017924    -0.161668
#          ref                                      0.247673    -0.192068
#          rim                                      0.098656    -0.226596
#          rmsd                                    -0.072713    -0.137738
#          shape_complementarity                    0.237436    -0.032395
#          solvation_energy                        -0.040630     0.052442
#          support                                  0.063703    -0.231430
#          total_interface_residues                 0.132631    -0.257998
#          divergence_combined_per_res             -0.084686    -0.002728
#          divergence_evolution_per_res             0.011176     0.000464
#          divergence_fragment_per_res             -0.054765     0.056076
#          divergence_interface_per_res            -0.172280     0.117338
#          protocol_energy_distance_sum             0.044467     0.071243
#          protocol_seq_distance_sum                0.000474    -0.019886
#          protocol_similarity_sum                 -0.038403     0.049628
#
# protocol                                                                      \
# metric                                     percent_fragment unique_fragments
# protocol metric
# pose     average_fragment_z_score                 -0.152573        -0.212802
#          interface_b_factor_per_res                     NaN              NaN
#          nanohedra_score                           0.448053         0.929539
#          observations                              0.095699        -0.139045
#          percent_fragment                          1.000000         0.452430
#          unique_fragments                          0.452430         1.000000
#          buns_heavy_total                         -0.458066         0.019249
#          buns_hpol_total                          -0.360564         0.049452
#          buns_per_ang                             -0.317582        -0.054776
#          buns_total                               -0.451680         0.027422
#          contact_count                            -0.390317         0.170712
#          core                                     -0.487657         0.187521
#          cst_weight                               -0.462712         0.089756
#          fsp_energy                               -0.459029        -0.508786
#          int_area_hydrophobic                     -0.461538         0.238407
#          int_area_polar                           -0.574837         0.070061
#          int_area_total                           -0.521212         0.197314
#          int_composition_diff                     -0.350795         0.092181
#          int_connectivity_A                       -0.059132         0.023099
#          int_connectivity_B                       -0.245273         0.023611
#          int_energy_context_oligomer_A             0.297415         0.038320
#          int_energy_context_oligomer_B             0.376401        -0.119868
#          int_energy_res_summary_complex            0.412901        -0.172011
#          int_energy_res_summary_delta              0.189454        -0.327718
#          int_energy_res_summary_oligomer           0.443543        -0.103876
#          int_energy_res_summary_oligomer_A         0.340456         0.004507
#          int_energy_res_summary_oligomer_B         0.389401        -0.189684
#          int_separation                           -0.111012        -0.145589
#          interaction_energy_complex                0.174406        -0.314218
#          number_hbonds                            -0.423144         0.103714
#          observed_combined                         0.137410        -0.026112
#          observed_evolution                       -0.115877         0.030145
#          observed_fragment                         0.380849         0.286590
#          percent_core                              0.084821         0.102260
#          percent_int_area_hydrophobic              0.286611         0.227168
#          percent_int_area_polar                   -0.286611        -0.227168
#          percent_rim                               0.149212        -0.042547
#          percent_support                          -0.327620         0.035254
#          ref                                      -0.046659         0.266395
#          rim                                      -0.499822         0.102553
#          rmsd                                     -0.210331        -0.085881
#          shape_complementarity                     0.242138         0.224359
#          solvation_energy                          0.055464        -0.021628
#          support                                  -0.537903         0.083418
#          total_interface_residues                 -0.597390         0.145866
#          divergence_combined_per_res               0.131197        -0.095654
#          divergence_evolution_per_res              0.235823        -0.000930
#          divergence_fragment_per_res               0.175254        -0.036844
#          divergence_interface_per_res              0.099827        -0.191573
#          protocol_energy_distance_sum             -0.074100         0.045704
#          protocol_seq_distance_sum                -0.150443        -0.025098
#          protocol_similarity_sum                  -0.167653        -0.014681
#
# protocol                                                                     \
# metric                                     buns_heavy_total buns_hpol_total
# protocol metric
# pose     average_fragment_z_score                 -0.002064        0.034060
#          interface_b_factor_per_res                     NaN             NaN
#          nanohedra_score                          -0.004487        0.024434
#          observations                             -0.162751       -0.156362
#          percent_fragment                         -0.458066       -0.360564
#          unique_fragments                          0.019249        0.049452
#          buns_heavy_total                          1.000000        0.708409
#          buns_hpol_total                           0.708409        1.000000
#          buns_per_ang                              0.909867        0.770695
#          buns_total                                0.975523        0.838009
#          contact_count                             0.550091        0.492764
#          core                                      0.552147        0.554800
#          cst_weight                                0.652986        0.569919
#          fsp_energy                                0.202199        0.094609
#          int_area_hydrophobic                      0.528698        0.506645
#          int_area_polar                            0.497598        0.487216
#          int_area_total                            0.549716        0.529911
#          int_composition_diff                      0.516035        0.404148
#          int_connectivity_A                        0.231737        0.278031
#          int_connectivity_B                        0.266057        0.229176
#          int_energy_context_oligomer_A            -0.338066       -0.192873
#          int_energy_context_oligomer_B            -0.393572       -0.299988
#          int_energy_res_summary_complex           -0.494465       -0.378773
#          int_energy_res_summary_delta             -0.327437       -0.310464
#          int_energy_res_summary_oligomer          -0.484555       -0.349900
#          int_energy_res_summary_oligomer_A        -0.380450       -0.245215
#          int_energy_res_summary_oligomer_B        -0.442085       -0.351563
#          int_separation                            0.083561        0.042071
#          interaction_energy_complex               -0.362516       -0.332044
#          number_hbonds                             0.394854        0.441007
#          observed_combined                        -0.174060       -0.129648
#          observed_evolution                        0.056956        0.003824
#          observed_fragment                        -0.265812       -0.106096
#          percent_core                              0.072747        0.116412
#          percent_int_area_hydrophobic             -0.078522       -0.104996
#          percent_int_area_polar                    0.078522        0.104996
#          percent_rim                              -0.351098       -0.263295
#          percent_support                           0.580582        0.393164
#          ref                                       0.109515        0.244111
#          rim                                       0.353102        0.382803
#          rmsd                                      0.405447        0.278496
#          shape_complementarity                    -0.138578       -0.088705
#          solvation_energy                         -0.248781       -0.161513
#          support                                   0.702047        0.538241
#          total_interface_residues                  0.592618        0.560169
#          divergence_combined_per_res              -0.333390       -0.156395
#          divergence_evolution_per_res             -0.377355       -0.195006
#          divergence_fragment_per_res              -0.098546       -0.089518
#          divergence_interface_per_res             -0.456465       -0.329710
#          protocol_energy_distance_sum             -0.109601        0.038392
#          protocol_seq_distance_sum                 0.153268        0.196227
#          protocol_similarity_sum                   0.199473        0.181331
#
# protocol                                                            \
# metric                                     buns_per_ang buns_total
# protocol metric
# pose     average_fragment_z_score              0.024917   0.008986
#          interface_b_factor_per_res                 NaN        NaN
#          nanohedra_score                      -0.077606   0.003150
#          observations                         -0.091690  -0.162557
#          percent_fragment                     -0.317582  -0.451680
#          unique_fragments                     -0.054776   0.027422
#          buns_heavy_total                      0.909867   0.975523
#          buns_hpol_total                       0.770695   0.838009
#          buns_per_ang                          1.000000   0.933913
#          buns_total                            0.933913   1.000000
#          contact_count                         0.376995   0.558609
#          core                                  0.321909   0.579389
#          cst_weight                            0.477579   0.656869
#          fsp_energy                            0.214989   0.182269
#          int_area_hydrophobic                  0.262876   0.548587
#          int_area_polar                        0.249647   0.516631
#          int_area_total                        0.278695   0.570449
#          int_composition_diff                  0.427964   0.508916
#          int_connectivity_A                    0.207032   0.258278
#          int_connectivity_B                    0.227001   0.266925
#          int_energy_context_oligomer_A        -0.249602  -0.315311
#          int_energy_context_oligomer_B        -0.266483  -0.389967
#          int_energy_res_summary_complex       -0.307125  -0.487585
#          int_energy_res_summary_delta         -0.161594  -0.339542
#          int_energy_res_summary_oligomer      -0.310789  -0.470556
#          int_energy_res_summary_oligomer_A    -0.267459  -0.361868
#          int_energy_res_summary_oligomer_B    -0.278135  -0.440986
#          int_separation                        0.083511   0.070866
#          interaction_energy_complex           -0.223706  -0.371218
#          number_hbonds                         0.209484   0.426527
#          observed_combined                    -0.109670  -0.165142
#          observed_evolution                    0.018040   0.043019
#          observed_fragment                    -0.226713  -0.230440
#          percent_core                          0.036139   0.088286
#          percent_int_area_hydrophobic         -0.053793  -0.087563
#          percent_int_area_polar                0.053793   0.087563
#          percent_rim                          -0.290480  -0.343255
#          percent_support                       0.481166   0.551922
#          ref                                   0.014630   0.149321
#          rim                                   0.162912   0.378820
#          rmsd                                  0.338580   0.386045
#          shape_complementarity                -0.112540  -0.125940
#          solvation_energy                     -0.280575  -0.235083
#          support                               0.505566   0.687010
#          total_interface_residues              0.356443   0.612253
#          divergence_combined_per_res          -0.252737  -0.298797
#          divergence_evolution_per_res         -0.293273  -0.343777
#          divergence_fragment_per_res          -0.053143  -0.097238
#          divergence_interface_per_res         -0.399298  -0.439289
#          protocol_energy_distance_sum         -0.131045  -0.074224
#          protocol_seq_distance_sum             0.107893   0.172487
#          protocol_similarity_sum               0.135788   0.196273
#
# protocol                                                                       \
# metric                                     contact_count      core cst_weight
# protocol metric
# pose     average_fragment_z_score              -0.063317 -0.056268   0.035068
#          interface_b_factor_per_res                  NaN       NaN        NaN
#          nanohedra_score                        0.164404  0.182634   0.060782
#          observations                          -0.275943 -0.228759  -0.195465
#          percent_fragment                      -0.390317 -0.487657  -0.462712
#          unique_fragments                       0.170712  0.187521   0.089756
#          buns_heavy_total                       0.550091  0.552147   0.652986
#          buns_hpol_total                        0.492764  0.554800   0.569919
#          buns_per_ang                           0.376995  0.321909   0.477579
#          buns_total                             0.558609  0.579389   0.656869
#          contact_count                          1.000000  0.769744   0.652591
#          core                                   0.769744  1.000000   0.713110
#          cst_weight                             0.652591  0.713110   1.000000
#          fsp_energy                            -0.093064 -0.089684   0.095390
#          int_area_hydrophobic                   0.733469  0.916513   0.654550
#          int_area_polar                         0.530742  0.774490   0.606197
#          int_area_total                         0.696972  0.917885   0.678359
#          int_composition_diff                   0.660477  0.513008   0.594297
#          int_connectivity_A                     0.364034  0.361533   0.363784
#          int_connectivity_B                     0.269460  0.206620   0.247461
#          int_energy_context_oligomer_A         -0.465928 -0.420858  -0.210551
#          int_energy_context_oligomer_B         -0.480269 -0.493819  -0.340163
#          int_energy_res_summary_complex        -0.763343 -0.744846  -0.472862
#          int_energy_res_summary_delta          -0.713495 -0.672233  -0.378493
#          int_energy_res_summary_oligomer       -0.671359 -0.668770  -0.443295
#          int_energy_res_summary_oligomer_A     -0.530861 -0.501509  -0.294857
#          int_energy_res_summary_oligomer_B     -0.571291 -0.625881  -0.436313
#          int_separation                        -0.186029 -0.043171   0.115620
#          interaction_energy_complex            -0.788143 -0.632966  -0.457064
#          number_hbonds                          0.449378  0.638617   0.529689
#          observed_combined                     -0.160976 -0.179191  -0.219993
#          observed_evolution                     0.091753  0.114436   0.149362
#          observed_fragment                     -0.115618 -0.097620  -0.234656
#          percent_core                           0.157142  0.418585   0.124072
#          percent_int_area_hydrophobic           0.145621  0.006155  -0.063691
#          percent_int_area_polar                -0.145621 -0.006155   0.063691
#          percent_rim                           -0.395046 -0.484637  -0.299013
#          percent_support                        0.540028  0.392328   0.514152
#          ref                                    0.376279  0.421387   0.286470
#          rim                                    0.499383  0.554706   0.529284
#          rmsd                                   0.321543  0.320274   0.416698
#          shape_complementarity                  0.124902 -0.034821  -0.175588
#          solvation_energy                      -0.347714 -0.062662  -0.347625
#          support                                0.761229  0.729194   0.740419
#          total_interface_residues               0.778661  0.906879   0.747438
#          divergence_combined_per_res           -0.159766 -0.215296  -0.302984
#          divergence_evolution_per_res          -0.185549 -0.247005  -0.344379
#          divergence_fragment_per_res           -0.134111 -0.135581  -0.193409
#          divergence_interface_per_res          -0.453347 -0.342978  -0.517178
#          protocol_energy_distance_sum          -0.007192  0.089622  -0.027716
#          protocol_seq_distance_sum              0.137274  0.185174   0.192946
#          protocol_similarity_sum                0.174452  0.231489   0.157424
#
# protocol                                                                    \
# metric                                     fsp_energy int_area_hydrophobic
# protocol metric
# pose     average_fragment_z_score            0.179225            -0.089048
#          interface_b_factor_per_res               NaN                  NaN
#          nanohedra_score                    -0.530125             0.235562
#          observations                        0.080850            -0.211154
#          percent_fragment                   -0.459029            -0.461538
#          unique_fragments                   -0.508786             0.238407
#          buns_heavy_total                    0.202199             0.528698
#          buns_hpol_total                     0.094609             0.506645
#          buns_per_ang                        0.214989             0.262876
#          buns_total                          0.182269             0.548587
#          contact_count                      -0.093064             0.733469
#          core                               -0.089684             0.916513
#          cst_weight                          0.095390             0.654550
#          fsp_energy                          1.000000            -0.098228
#          int_area_hydrophobic               -0.098228             1.000000
#          int_area_polar                      0.092743             0.780449
#          int_area_total                     -0.037937             0.974045
#          int_composition_diff                0.007166             0.417413
#          int_connectivity_A                 -0.091926             0.271254
#          int_connectivity_B                  0.189365             0.126021
#          int_energy_context_oligomer_A       0.017966            -0.399459
#          int_energy_context_oligomer_B      -0.001965            -0.495425
#          int_energy_res_summary_complex      0.108036            -0.732058
#          int_energy_res_summary_delta        0.276633            -0.668731
#          int_energy_res_summary_oligomer     0.042131            -0.658286
#          int_energy_res_summary_oligomer_A   0.023252            -0.481307
#          int_energy_res_summary_oligomer_B   0.072858            -0.621893
#          int_separation                      0.194530            -0.059917
#          interaction_energy_complex          0.243803            -0.602393
#          number_hbonds                       0.031003             0.622665
#          observed_combined                  -0.073187            -0.211964
#          observed_evolution                  0.009855             0.085363
#          observed_fragment                  -0.327100            -0.078973
#          percent_core                       -0.144118             0.255464
#          percent_int_area_hydrophobic       -0.289374             0.098841
#          percent_int_area_polar              0.289374            -0.098841
#          percent_rim                         0.016252            -0.347988
#          percent_support                     0.165738             0.401549
#          ref                                -0.174667             0.368290
#          rim                                -0.014753             0.628603
#          rmsd                                0.108094             0.262145
#          shape_complementarity              -0.286709            -0.010829
#          solvation_energy                   -0.033667            -0.003234
#          support                             0.117800             0.721107
#          total_interface_residues           -0.028293             0.890506
#          divergence_combined_per_res        -0.084565            -0.235585
#          divergence_evolution_per_res       -0.194199            -0.259347
#          divergence_fragment_per_res         0.133890            -0.118708
#          divergence_interface_per_res        0.026090            -0.313139
#          protocol_energy_distance_sum       -0.081151             0.103876
#          protocol_seq_distance_sum           0.053813             0.191200
#          protocol_similarity_sum             0.060476             0.226493
#
# protocol                                                                  \
# metric                                     int_area_polar int_area_total
# protocol metric
# pose     average_fragment_z_score                0.039031      -0.050864
#          interface_b_factor_per_res                   NaN            NaN
#          nanohedra_score                         0.043322       0.185185
#          observations                           -0.196700      -0.210792
#          percent_fragment                       -0.574837      -0.521212
#          unique_fragments                        0.070061       0.197314
#          buns_heavy_total                        0.497598       0.549716
#          buns_hpol_total                         0.487216       0.529911
#          buns_per_ang                            0.249647       0.278695
#          buns_total                              0.516631       0.570449
#          contact_count                           0.530742       0.696972
#          core                                    0.774490       0.917885
#          cst_weight                              0.606197       0.678359
#          fsp_energy                              0.092743      -0.037937
#          int_area_hydrophobic                    0.780449       0.974045
#          int_area_polar                          1.000000       0.894761
#          int_area_total                          0.894761       1.000000
#          int_composition_diff                    0.330819       0.414844
#          int_connectivity_A                      0.219486       0.272026
#          int_connectivity_B                      0.230417       0.177078
#          int_energy_context_oligomer_A          -0.297606      -0.385879
#          int_energy_context_oligomer_B          -0.390313      -0.481392
#          int_energy_res_summary_complex         -0.569754      -0.712309
#          int_energy_res_summary_delta           -0.490120      -0.637377
#          int_energy_res_summary_oligomer        -0.516963      -0.642760
#          int_energy_res_summary_oligomer_A      -0.360986      -0.465954
#          int_energy_res_summary_oligomer_B      -0.489215      -0.606564
#          int_separation                          0.051494      -0.017611
#          interaction_energy_complex             -0.413963      -0.566731
#          number_hbonds                           0.790178       0.708658
#          observed_combined                      -0.170107      -0.207223
#          observed_evolution                      0.115032       0.100860
#          observed_fragment                      -0.120134      -0.098385
#          percent_core                            0.106914       0.220645
#          percent_int_area_hydrophobic           -0.501543      -0.100561
#          percent_int_area_polar                  0.501543       0.100561
#          percent_rim                            -0.193340      -0.317488
#          percent_support                         0.343638       0.405528
#          ref                                     0.311505       0.372848
#          rim                                     0.665268       0.669770
#          rmsd                                    0.208718       0.258249
#          shape_complementarity                  -0.155294      -0.065303
#          solvation_energy                        0.095392       0.025835
#          support                                 0.653152       0.738793
#          total_interface_residues                0.808884       0.911956
#          divergence_combined_per_res            -0.209531      -0.240538
#          divergence_evolution_per_res           -0.257370      -0.272569
#          divergence_fragment_per_res            -0.107031      -0.126480
#          divergence_interface_per_res           -0.146351      -0.272146
#          protocol_energy_distance_sum            0.131725       0.121545
#          protocol_seq_distance_sum               0.206897       0.205560
#          protocol_similarity_sum                 0.187531       0.226568
#
# protocol                                                         \
# metric                                     int_composition_diff
# protocol metric
# pose     average_fragment_z_score                     -0.019228
#          interface_b_factor_per_res                         NaN
#          nanohedra_score                               0.087734
#          observations                                 -0.220982
#          percent_fragment                             -0.350795
#          unique_fragments                              0.092181
#          buns_heavy_total                              0.516035
#          buns_hpol_total                               0.404148
#          buns_per_ang                                  0.427964
#          buns_total                                    0.508916
#          contact_count                                 0.660477
#          core                                          0.513008
#          cst_weight                                    0.594297
#          fsp_energy                                    0.007166
#          int_area_hydrophobic                          0.417413
#          int_area_polar                                0.330819
#          int_area_total                                0.414844
#          int_composition_diff                          1.000000
#          int_connectivity_A                            0.273057
#          int_connectivity_B                            0.417479
#          int_energy_context_oligomer_A                -0.365366
#          int_energy_context_oligomer_B                -0.457096
#          int_energy_res_summary_complex               -0.572219
#          int_energy_res_summary_delta                 -0.409504
#          int_energy_res_summary_oligomer              -0.558220
#          int_energy_res_summary_oligomer_A            -0.428179
#          int_energy_res_summary_oligomer_B            -0.494979
#          int_separation                               -0.022618
#          interaction_energy_complex                   -0.531732
#          number_hbonds                                 0.263788
#          observed_combined                            -0.100564
#          observed_evolution                            0.077306
#          observed_fragment                            -0.079470
#          percent_core                                 -0.009376
#          percent_int_area_hydrophobic                  0.020645
#          percent_int_area_polar                       -0.020645
#          percent_rim                                  -0.316990
#          percent_support                               0.617536
#          ref                                           0.334698
#          rim                                           0.382501
#          rmsd                                          0.253937
#          shape_complementarity                        -0.017748
#          solvation_energy                             -0.435537
#          support                                       0.717332
#          total_interface_residues                      0.595764
#          divergence_combined_per_res                  -0.166278
#          divergence_evolution_per_res                 -0.188719
#          divergence_fragment_per_res                  -0.200109
#          divergence_interface_per_res                 -0.404060
#          protocol_energy_distance_sum                 -0.069837
#          protocol_seq_distance_sum                     0.110999
#          protocol_similarity_sum                       0.087652
#
# protocol                                                       \
# metric                                     int_connectivity_A
# protocol metric
# pose     average_fragment_z_score                    0.059585
#          interface_b_factor_per_res                       NaN
#          nanohedra_score                             0.016692
#          observations                                0.014670
#          percent_fragment                           -0.059132
#          unique_fragments                            0.023099
#          buns_heavy_total                            0.231737
#          buns_hpol_total                             0.278031
#          buns_per_ang                                0.207032
#          buns_total                                  0.258278
#          contact_count                               0.364034
#          core                                        0.361533
#          cst_weight                                  0.363784
#          fsp_energy                                 -0.091926
#          int_area_hydrophobic                        0.271254
#          int_area_polar                              0.219486
#          int_area_total                              0.272026
#          int_composition_diff                        0.273057
#          int_connectivity_A                          1.000000
#          int_connectivity_B                         -0.153416
#          int_energy_context_oligomer_A              -0.210063
#          int_energy_context_oligomer_B               0.000239
#          int_energy_res_summary_complex             -0.237701
#          int_energy_res_summary_delta               -0.235709
#          int_energy_res_summary_oligomer            -0.199359
#          int_energy_res_summary_oligomer_A          -0.204480
#          int_energy_res_summary_oligomer_B          -0.101289
#          int_separation                              0.047906
#          interaction_energy_complex                 -0.315272
#          number_hbonds                               0.142928
#          observed_combined                          -0.096862
#          observed_evolution                         -0.068298
#          observed_fragment                           0.016983
#          percent_core                                0.202797
#          percent_int_area_hydrophobic                0.020159
#          percent_int_area_polar                     -0.020159
#          percent_rim                                -0.319189
#          percent_support                             0.213224
#          ref                                         0.363068
#          rim                                         0.120164
#          rmsd                                        0.185941
#          shape_complementarity                      -0.037103
#          solvation_energy                           -0.212359
#          support                                     0.299233
#          total_interface_residues                    0.324323
#          divergence_combined_per_res                -0.124066
#          divergence_evolution_per_res               -0.139756
#          divergence_fragment_per_res                -0.016335
#          divergence_interface_per_res               -0.235162
#          protocol_energy_distance_sum                0.114214
#          protocol_seq_distance_sum                   0.057799
#          protocol_similarity_sum                     0.112079
#
# protocol                                                       \
# metric                                     int_connectivity_B
# protocol metric
# pose     average_fragment_z_score                    0.017138
#          interface_b_factor_per_res                       NaN
#          nanohedra_score                            -0.010549
#          observations                               -0.202223
#          percent_fragment                           -0.245273
#          unique_fragments                            0.023611
#          buns_heavy_total                            0.266057
#          buns_hpol_total                             0.229176
#          buns_per_ang                                0.227001
#          buns_total                                  0.266925
#          contact_count                               0.269460
#          core                                        0.206620
#          cst_weight                                  0.247461
#          fsp_energy                                  0.189365
#          int_area_hydrophobic                        0.126021
#          int_area_polar                              0.230417
#          int_area_total                              0.177078
#          int_composition_diff                        0.417479
#          int_connectivity_A                         -0.153416
#          int_connectivity_B                          1.000000
#          int_energy_context_oligomer_A              -0.104656
#          int_energy_context_oligomer_B              -0.352232
#          int_energy_res_summary_complex             -0.235961
#          int_energy_res_summary_delta               -0.139974
#          int_energy_res_summary_oligomer            -0.253133
#          int_energy_res_summary_oligomer_A          -0.147368
#          int_energy_res_summary_oligomer_B          -0.291953
#          int_separation                              0.025750
#          interaction_energy_complex                 -0.189115
#          number_hbonds                               0.142109
#          observed_combined                          -0.059528
#          observed_evolution                          0.049442
#          observed_fragment                           0.019541
#          percent_core                               -0.144637
#          percent_int_area_hydrophobic               -0.200953
#          percent_int_area_polar                      0.200953
#          percent_rim                                -0.175011
#          percent_support                             0.396714
#          ref                                         0.411429
#          rim                                         0.186513
#          rmsd                                        0.049542
#          shape_complementarity                      -0.058009
#          solvation_energy                           -0.163687
#          support                                     0.427712
#          total_interface_residues                    0.299430
# ...
# metric                                     divergence_interface_per_res
# protocol metric
# pose     average_fragment_z_score                              0.046756
#          interface_b_factor_per_res                                 NaN
#          nanohedra_score                                      -0.172280
#          observations                                          0.117338
#          percent_fragment                                      0.099827
#          unique_fragments                                     -0.191573
#          buns_heavy_total                                     -0.456465
#          buns_hpol_total                                      -0.329710
#          buns_per_ang                                         -0.399298
#          buns_total                                           -0.439289
#          contact_count                                        -0.453347
#          core                                                 -0.342978
#          cst_weight                                           -0.517178
#          fsp_energy                                            0.026090
#          int_area_hydrophobic                                 -0.313139
#          int_area_polar                                       -0.146351
#          int_area_total                                       -0.272146
#          int_composition_diff                                 -0.404060
#          int_connectivity_A                                   -0.235162
#          int_connectivity_B                                   -0.036142
#          int_energy_context_oligomer_A                         0.174514
#          int_energy_context_oligomer_B                         0.160896
#          int_energy_res_summary_complex                        0.296598
#          int_energy_res_summary_delta                          0.215955
#          int_energy_res_summary_oligomer                       0.289463
#          int_energy_res_summary_oligomer_A                     0.225428
#          int_energy_res_summary_oligomer_B                     0.238135
#          int_separation                                       -0.109058
#          interaction_energy_complex                            0.336604
#          number_hbonds                                        -0.161047
#          observed_combined                                     0.203657
#          observed_evolution                                    0.050632
#          observed_fragment                                     0.244088
#          percent_core                                         -0.234498
#          percent_int_area_hydrophobic                         -0.221302
#          percent_int_area_polar                                0.221302
#          percent_rim                                           0.299791
#          percent_support                                      -0.445561
#          ref                                                   0.036330
#          rim                                                  -0.090990
#          rmsd                                                 -0.385978
#          shape_complementarity                                 0.108625
#          solvation_energy                                      0.394778
#          support                                              -0.456573
#          total_interface_residues                             -0.290211
#          divergence_combined_per_res                           0.561871
#          divergence_evolution_per_res                          0.542698
#          divergence_fragment_per_res                           0.336062
#          divergence_interface_per_res                          1.000000
#          protocol_energy_distance_sum                          0.152019
#          protocol_seq_distance_sum                            -0.167401
#          protocol_similarity_sum                              -0.107256
#
# protocol                                                                 \
# metric                                     protocol_energy_distance_sum
# protocol metric
# pose     average_fragment_z_score                              0.003924
#          interface_b_factor_per_res                                 NaN
#          nanohedra_score                                       0.044467
#          observations                                          0.071243
#          percent_fragment                                     -0.074100
#          unique_fragments                                      0.045704
#          buns_heavy_total                                     -0.109601
#          buns_hpol_total                                       0.038392
#          buns_per_ang                                         -0.131045
#          buns_total                                           -0.074224
#          contact_count                                        -0.007192
#          core                                                  0.089622
#          cst_weight                                           -0.027716
#          fsp_energy                                           -0.081151
#          int_area_hydrophobic                                  0.103876
#          int_area_polar                                        0.131725
#          int_area_total                                        0.121545
#          int_composition_diff                                 -0.069837
#          int_connectivity_A                                    0.114214
#          int_connectivity_B                                    0.021463
#          int_energy_context_oligomer_A                         0.080107
#          int_energy_context_oligomer_B                         0.016882
#          int_energy_res_summary_complex                        0.058858
#          int_energy_res_summary_delta                         -0.104870
#          int_energy_res_summary_oligomer                       0.102016
#          int_energy_res_summary_oligomer_A                     0.087304
#          int_energy_res_summary_oligomer_B                     0.013252
#          int_separation                                        0.055904
#          interaction_energy_complex                           -0.074071
#          number_hbonds                                         0.082690
#          observed_combined                                    -0.106828
#          observed_evolution                                   -0.196074
#          observed_fragment                                     0.122227
#          percent_core                                          0.002432
#          percent_int_area_hydrophobic                         -0.027929
#          percent_int_area_polar                                0.027929
#          percent_rim                                          -0.002016
#          percent_support                                      -0.128409
#          ref                                                   0.190707
#          rim                                                   0.115383
#          rmsd                                                 -0.357296
#          shape_complementarity                                -0.028457
#          solvation_energy                                      0.098163
#          support                                              -0.043147
#          total_interface_residues                              0.101289
#          divergence_combined_per_res                           0.059162
#          divergence_evolution_per_res                          0.065687
#          divergence_fragment_per_res                          -0.028050
#          divergence_interface_per_res                          0.152019
#          protocol_energy_distance_sum                          1.000000
#          protocol_seq_distance_sum                             0.117372
#          protocol_similarity_sum                               0.235835
#
# protocol                                                              \
# metric                                     protocol_seq_distance_sum
# protocol metric
# pose     average_fragment_z_score                          -0.009299
#          interface_b_factor_per_res                              NaN
#          nanohedra_score                                    0.000474
#          observations                                      -0.019886
#          percent_fragment                                  -0.150443
#          unique_fragments                                  -0.025098
#          buns_heavy_total                                   0.153268
#          buns_hpol_total                                    0.196227
#          buns_per_ang                                       0.107893
#          buns_total                                         0.172487
#          contact_count                                      0.137274
#          core                                               0.185174
#          cst_weight                                         0.192946
#          fsp_energy                                         0.053813
#          int_area_hydrophobic                               0.191200
#          int_area_polar                                     0.206897
#          int_area_total                                     0.205560
#          int_composition_diff                               0.110999
#          int_connectivity_A                                 0.057799
#          int_connectivity_B                                 0.081859
#          int_energy_context_oligomer_A                     -0.064264
#          int_energy_context_oligomer_B                     -0.072068
#          int_energy_res_summary_complex                    -0.123723
#          int_energy_res_summary_delta                      -0.052427
#          int_energy_res_summary_oligomer                   -0.136986
#          int_energy_res_summary_oligomer_A                 -0.110525
#          int_energy_res_summary_oligomer_B                 -0.073793
#          int_separation                                     0.082936
#          interaction_energy_complex                        -0.060999
#          number_hbonds                                      0.149685
#          observed_combined                                 -0.173496
#          observed_evolution                                -0.267745
#          observed_fragment                                 -0.090480
#          percent_core                                       0.061729
#          percent_int_area_hydrophobic                      -0.081379
#          percent_int_area_polar                             0.081379
#          percent_rim                                       -0.071698
#          percent_support                                    0.168655
#          ref                                               -0.000629
#          rim                                                0.129561
#          rmsd                                               0.032199
#          shape_complementarity                             -0.118193
#          solvation_energy                                  -0.069855
#          support                                            0.195813
#          total_interface_residues                           0.169837
#          divergence_combined_per_res                       -0.180218
#          divergence_evolution_per_res                      -0.186170
#          divergence_fragment_per_res                       -0.077887
#          divergence_interface_per_res                      -0.167401
#          protocol_energy_distance_sum                       0.117372
#          protocol_seq_distance_sum                          1.000000
#          protocol_similarity_sum                            0.145083
#
# protocol
# metric                                     protocol_similarity_sum
# protocol metric
# pose     average_fragment_z_score                         0.069604
#          interface_b_factor_per_res                            NaN
#          nanohedra_score                                 -0.038403
#          observations                                     0.049628
#          percent_fragment                                -0.167653
#          unique_fragments                                -0.014681
#          buns_heavy_total                                 0.199473
#          buns_hpol_total                                  0.181331
#          buns_per_ang                                     0.135788
#          buns_total                                       0.196273
#          contact_count                                    0.174452
#          core                                             0.231489
#          cst_weight                                       0.157424
#          fsp_energy                                       0.060476
#          int_area_hydrophobic                             0.226493
#          int_area_polar                                   0.187531
#          int_area_total                                   0.226568
#          int_composition_diff                             0.087652
#          int_connectivity_A                               0.112079
#          int_connectivity_B                               0.093735
#          int_energy_context_oligomer_A                   -0.144275
#          int_energy_context_oligomer_B                   -0.133287
#          int_energy_res_summary_complex                  -0.193063
#          int_energy_res_summary_delta                    -0.134460
#          int_energy_res_summary_oligomer                 -0.190117
#          int_energy_res_summary_oligomer_A               -0.166832
#          int_energy_res_summary_oligomer_B               -0.142778
#          int_separation                                  -0.024356
#          interaction_energy_complex                      -0.112003
#          number_hbonds                                    0.135534
#          observed_combined                               -0.331283
#          observed_evolution                              -0.334519
#          observed_fragment                               -0.054155
#          percent_core                                     0.103862
#          percent_int_area_hydrophobic                     0.007863
#          percent_int_area_polar                          -0.007863
#          percent_rim                                     -0.177666
#          percent_support                                  0.150326
#          ref                                              0.053631
#          rim                                              0.094969
#          rmsd                                             0.029804
#          shape_complementarity                            0.003331
#          solvation_energy                                 0.000491
#          support                                          0.215159
#          total_interface_residues                         0.207173
#          divergence_combined_per_res                     -0.191327
#          divergence_evolution_per_res                    -0.202194
#          divergence_fragment_per_res                     -0.012509
#          divergence_interface_per_res                    -0.107256
#          protocol_energy_distance_sum                     0.235835
#          protocol_seq_distance_sum                        0.145083
#          protocol_similarity_sum                          1.000000

# %%
nanohedra_quantitative_columns = [
#     'component_1_c_terminal_orientation', 'component_1_max_radius',
#     'component_1_n_terminal_orientation', 'component_1_number_of_residues',
#     'component_2_c_terminal_orientation', 'component_2_max_radius',
#     'component_2_n_terminal_orientation', 'component_2_number_of_residues', 
#     'interface_b_factor_per_res', 
    'multiple_fragment_ratio', 
    'nanohedra_score', 'nanohedra_score_central', 
    'nanohedra_score_per_res', 'nanohedra_score_central_per_res_central', 
    'number_fragment_residues_central', 'number_fragment_residues_total', 
#     'percent_fragment_coil', 'percent_fragment_helix', 'percent_fragment_strand',
    'percent_residues_fragment_center', 'percent_residues_fragment_total',
    'total_interface_residues', 'number_fragments']

# %% [markdown]
# Edit these metrics to look at the correlation across a given dataframe between specific metrics you are interested in

# %%
# THE DATAFRAME OF INTEREST
# subset_df = protocol_df.droplevel(0, axis=1)
subset_df = giant_cluster_df
# subset_df = filtered_df
# display(subset_df)
# THE METRICS OF INTEREST
# metrics_of_interest = ['nanohedra_score', 'nanohedra_score_central', 'nanohedra_score_per_res', 'total_interface_residues']
metrics_of_interest = nanohedra_quantitative_columns

# %%
corr_df = subset_df[metrics_of_interest]
corr = corr_df.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:xlabel='metric', ylabel='metric'>

# %% [markdown]
# ### Here you could plot pairs of correlated variables
# add the pairs as a tuple in the metric pairs list

# %%
# corr_df = protocol_df.droplevel(0, axis=1)
# display(corr_df)
# subset_df = protocol_df.droplevel(0, axis=1)
metric_pairs = [('nanohedra_score', 'nanohedra_score_central'),
                ('nanohedra_score', 'total_interface_residues'),
                ('nanohedra_score_per_res', 'total_interface_residues'),
                 ]
# for x, y in combinations(metric_pairs):
with sns.plotting_context("notebook", font_scale=1.5):
    for x, y in metric_pairs:
        display(subset_df[x].corr(subset_df[y]))
        ax = sns.lmplot(x=x, y=y, data=subset_df)
        if y == 'int_energy_res_summary_delta':
            y = 'predicted_binding_energy'
        if x == 'protocol_energy_distance_sum':
            x = 'protocol_distance'
        ax.set(xlabel=' '.join(x.split('_')).title(), ylabel=' '.join(y.split('_')).title())
        plt.show()
with sns.plotting_context("notebook", font_scale=1.5):
    for x, y in bar_plot_pairs:
        display(subset_df[x].corr(subset_df[y]))
    #     ax = sns.catplot(x=x, y=y, kind='violin', data=subset_df)
#         ax = sns.lmplot(x=x, y=y, data=subset_df, x_estimator=np.mean)
        ax = sns.regplot(x=x, y=y, data=subset_df, x_estimator=np.mean)
        if y == 'int_energy_res_summary_delta':
            y = 'predicted_binding_energy'
        elif y == 'int_area_hydrophobic':
            y = 'hydrophobic_buried_surface_area'
        ax.set(xlabel='SSM elements', ylabel=' '.join(y.split('_')).title())  # format into a fancier axis title
        plt.show()
# sns.pairplot(subset_df, x_vars=['shape_complementarity', 'int_energy_res_summary_delta'], y_vars=['unique_fragments'],
#              height=5, aspect=.8, kind="reg")
# sns.pairplot(subset_df, y_vars=['shape_complementarity', 'int_energy_res_summary_delta'], x_vars=['unique_fragments'],
#             aspect=.8, kind="reg") # height=5
# sns.lmplot(x=y, y=x, data=subset_df, x_estimator=np.mean, col='vars', hue='vars')
# Out:
# 0.8419234180219471
# -0.05113645277407907
# -0.44805897921781257
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'protocol_energy_distance_sum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-a35713fce988> in <module>
#      10 with sns.plotting_context("notebook", font_scale=1.5):
#      11     for x, y in metric_pairs:
# ---> 12         display(subset_df[x].corr(subset_df[y]))
#      13         ax = sns.lmplot(x=x, y=y, data=subset_df)
#      14         if y == 'int_energy_res_summary_delta':
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'protocol_energy_distance_sum'

# %%
# corr_df = protocol_df.droplevel(0, axis=1)
# display(corr_df)
subset_df = protocol_df.droplevel(0, axis=1)
metric_pairs = [('divergence_evolution_per_res', 'divergence_interface_per_res'), 
                ('interaction_energy_complex', 'int_energy_res_summary_delta'),
                ('divergence_interface_per_res', 'contact_count'), 
                ('shape_complementarity', 'int_separation'), ]
# for x, y in combinations(metric_pairs):
for x, y in metric_pairs:
    display(subset_df[x].corr(subset_df[y]))
    sns.lmplot(x=x, y=y, data=subset_df)
# Out:
# 0.5358091674094778
# 0.8198734978002182
# -0.4348166451353058
# -0.9396953085946905

# %%
metrics_of_interest = {'observed_evolution': '% Residues Obs. Evol.',
                       'int_area_total': 'Buried Surface Area (BSA)',
                       'shape_complementarity': 'Shape Complementarity',
                       'int_energy_res_summary_delta': 'Predicted Binding Energy', 
#                        'contact_count': 'Carbon-Carbon Contacts', 
                       'percent_int_area_hydrophobic': 'Hydrophobic BSA',
                       'number_hbonds': 'H-bonds',
                       'buns_total': 'Buried Unsat. H-bonds',
#                        'core', 'rim', 'support']  #'interaction_energy_complex', 'int_area_hydrophobic',
#                              'int_area_polar', 'int_area_total']
                      }

# %%
subset_df = protocol_df.droplevel(0, axis=1)
subset_df = subset_df['protocol_energy_distance_sum']
protocol_energy = {'protocol_energy_distance_sum': 'Protocol Distance'}
metrics_of_interest2 = metrics_of_interest.copy()
metrics_of_interest2.update(protocol_energy)
constraint_corr_df = pd.merge(no_constraint_protocol_df.droplevel(0, axis=1), subset_df, left_index=True, right_index=True)
subset_constraint_corr_df = constraint_corr_df[list(metrics_of_interest.keys())]  # + list(protocol_energy.keys())
subset_constraint_corr_df = subset_constraint_corr_df.rename(columns=metrics_of_interest)
corr = subset_constraint_corr_df.corr(method='spearman')
# mask = np.ones_like((len(corr), len(corr) - 1), dtype=np.bool)

# Generate a mask to display only correlations of interest
mask = np.ones_like(corr, dtype=np.bool)
# display(mask)
for i, row in enumerate(mask):
    mask[i][-1] = False
# display(mask)
# display(mask[: ,-1])
# mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Plot
with sns.plotting_context("notebook", font_scale=1.5):
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(6, 4))

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
                square=True, linewidths=.5, # cbar_kws={"shrink": .5},
                annot=True, xticklabels=False)

# %%
# corr_df = protocol_df.droplevel(0, axis=1)
# display(corr_df)
# subset_df = protocol_df.droplevel(0, axis=1)
# metric_pairs = [
# #                 ('divergence_evolution_per_res', 'divergence_interface_per_res'), 
# #                 ('interaction_energy_complex', 'int_energy_res_summary_delta'),
# #                 ('divergence_interface_per_res', 'contact_count'), 
# #                 ('shape_complementarity', 'int_separation'),
# #                 ('percent_support', 'int_composition_diff'),
# #                 ('percent_rim', 'int_composition_diff'),
# #                 ('percent_core', 'int_composition_diff'),
# #                 ('int_composition_diff', 'int_energy_res_summary_delta'),
#                 ('protocol_energy_distance_sum', 'int_composition_diff'),
#                 ('observed_evolution', 'int_energy_res_summary_delta'),
#                 ('protocol_energy_distance_sum', 'int_energy_res_summary_delta'),
#                 ('unique_fragments', 'int_composition_diff')
# #                 ('observed_evolution', 'protocol_energy_distance_sum'),
# #                 ('observed_evolution', 'protocol_seq_distance_sum'),
# #                 ('percent_fragment', 'int_area_hydrophobic'),
#                 ]
subset_df = constraint_corr_df
from itertools import repeat
metric_pairs = zip(repeat('protocol_energy_distance_sum'), constraint_corr_df.columns.to_list())
# bar_plot_pairs = [
#                   ('unique_fragments', 'int_area_hydrophobic'),
#                   ('unique_fragments', 'shape_complementarity'),
#                   ('unique_fragments', 'int_energy_res_summary_delta'),
#                   ('unique_fragments', 'int_composition_diff')
#                  ]
# for x, y in combinations(metric_pairs):
for x, y in metric_pairs:
    display(subset_df[x].corr(subset_df[y]))
    ax = sns.lmplot(x=x, y=y, data=subset_df)
    if y == 'int_energy_res_summary_delta':
        y = 'predicted_binding_energy'
    if x == 'protocol_energy_distance_sum':
        x = 'protocol_distance'
    ax.set(xlabel=' '.join(x.split('_')).title(), ylabel=' '.join(y.split('_')).title())
    plt.show()
# for x, y in bar_plot_pairs:
#     display(subset_df[x].corr(subset_df[y]))
# #     ax = sns.catplot(x=x, y=y, kind='violin', data=subset_df)
#     ax = sns.lmplot(x=x, y=y, data=subset_df, x_estimator=np.mean)
#     if y == 'int_energy_res_summary_delta':
#         y = 'predicted_binding_energy'
#     elif y == 'int_area_hydrophobic':
#         y = 'hydrophobic_buried_surface_area'
#     ax.set(xlabel='SSC elements', ylabel=' '.join(y.split('_')).title())
#     plt.show()
# Out:
# -0.04896870293552273
# 0.029807015989423515
# 0.1093822884764262
# -0.11056487163124432
# -0.10115573712066464
# 0.0767432887230824
# 0.05537641329509701
# 0.06912498379015046
# 0.06575461634767506
# -0.009475537181021105
# -0.023026973333753604
# -0.03461434833483293
# 0.13714494644246372
# -0.06785635968687807
# -0.06390743279626111
# -0.1111422783025701
# 0.03497266934384523
# 0.052375776552585296
# -0.01910454984823349
# 1.0

# %%
protocols_of_interest_freeVnot = {'no_constraint': 'Free', 'combo_profile': 'Constraint'}  # 'limit_to_profile', 'consensus',
protocols_of_interest_all = {'no_constraint': 'Free', 'combo_profile': 'Constraint', 'limit_to_profile': 'Latent Evolution', 'favor_profile': 'Weighted Constraint'}  # 'limit_to_profile', 'consensus',
protocols_of_interest = protocols_of_interest_freeVnot

# %% [markdown]
# ## Reformat the data to pull specific columns and make a vertically stacked dataframe to produce Bar graphs which have a normalized z-value and are thus comparable across different scalar ranges

# %%
# from sklearn.preprocessing import StandardScaler

# normalized_df = design_protocols_df.subtract(design_protocols_df.min())

# .stack() takes a multiindex column header and re-orients (almost transposes) the data onto the index
bar_df = pd.DataFrame(design_protocols_df.stack().stack())
bar_df['Metric'] = bar_df.index.get_level_values(1)
bar_df['Protocol'] = bar_df.index.get_level_values(2)
bar_df = bar_df.rename({0: 'Value'}, axis=1)
# display(bar_df)
# display(bar_df.loc[:, ['Protocol']].isin(protocols_of_interest)['Protocol'])
bar_df = bar_df[bar_df.loc[idx[:, :, :], ['Protocol']].isin(protocols_of_interest.keys())['Protocol']]
bar_df = bar_df[bar_df.loc[idx[:, :, :], ['Metric']].isin(metrics_of_interest.keys())['Metric']]
# bar_df = bar_df[bar_df.loc[:, ['Protocol']] == protocols_of_interest]
display(bar_df)
# Out:
#                                                                                       Value  \
#                                     metric                       protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 buns_total                   combo_profile     2.642857
#                                                                  no_constraint     6.400000
#                                     int_area_total               combo_profile  1645.445243
#                                                                  no_constraint  1795.745410
#                                     int_energy_res_summary_delta combo_profile   -36.732404
# ...                                                                                     ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  observed_evolution           no_constraint     1.000000
#                                     percent_int_area_hydrophobic combo_profile     0.614864
#                                                                  no_constraint     0.541758
#                                     shape_complementarity        combo_profile     0.639006
#                                                                  no_constraint     0.649500
#
#                                                                                                       Metric  \
#                                     metric                       protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 buns_total                   combo_profile                    buns_total
#                                                                  no_constraint                    buns_total
#                                     int_area_total               combo_profile                int_area_total
#                                                                  no_constraint                int_area_total
#                                     int_energy_res_summary_delta combo_profile  int_energy_res_summary_delta
# ...                                                                                                      ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  observed_evolution           no_constraint            observed_evolution
#                                     percent_int_area_hydrophobic combo_profile  percent_int_area_hydrophobic
#                                                                  no_constraint  percent_int_area_hydrophobic
#                                     shape_complementarity        combo_profile         shape_complementarity
#                                                                  no_constraint         shape_complementarity
#
#                                                                                      Protocol
#                                     metric                       protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 buns_total                   combo_profile  combo_profile
#                                                                  no_constraint  no_constraint
#                                     int_area_total               combo_profile  combo_profile
#                                                                  no_constraint  no_constraint
#                                     int_energy_res_summary_delta combo_profile  combo_profile
# ...                                                                                       ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  observed_evolution           no_constraint  no_constraint
#                                     percent_int_area_hydrophobic combo_profile  combo_profile
#                                                                  no_constraint  no_constraint
#                                     shape_complementarity        combo_profile  combo_profile
#                                                                  no_constraint  no_constraint
#
# [9086 rows x 3 columns]

# %%
# First, normalize the data according to protocol groups
# display(bar_df.groupby('Metric').mean())
display(bar_df.groupby('Metric').transform(lambda x: (x - x.mean()) / x.std()))
normalize_df = bar_df.groupby('Metric').transform(lambda x: (x - x.mean()) / x.std())

# display(bar_df.groupby('Metric').min())
bar_s = bar_df.groupby('Metric').mean().squeeze()
# bar_s['int_energy_res_summary_delta'] = bar_s['int_energy_res_summary_delta'] * -1
# inverted_energy_df = bar_df
# inverted_energy_df['Value'] = bar_df.loc[idx[:, bar_df.index.get_level_values(1) == 'int_energy_res_summary_delta', :], 'Value'] * -1
# display(inverted_energy_df)
mean_bar_s = bar_s
final_bar_df = bar_df
# display(mean_bar_s)
# bar_df[bar_df.loc[:, ['Metric']].isin(mean_bar_df)['Protocol']]
new_bar_l = []
for metric, metric_mean in zip(mean_bar_s.index, mean_bar_s):
#     print(metric_mean)
#     print(metric)
#     display(bar_df.loc[idx[:, bar_df.index.get_level_values(1) == metric, :], :])
#     print(bar_df[bar_df.loc[:, ['Metric']] == metric])
#     display(pd.DataFrame(bar_df.loc[idx[:, bar_df.index.get_level_values(1) == metric, :], 'Value'] / metric_mean))
    if metric == 'int_energy_res_summary_delta':
        temp_df = pd.DataFrame(bar_df.loc[idx[:, bar_df.index.get_level_values(1) == metric, :], 'Value'] / metric_mean)
        new_bar_l.append(1 - (temp_df - 1))
    else:
        new_bar_l.append(pd.DataFrame(bar_df.loc[idx[:, bar_df.index.get_level_values(1) == metric, :], 'Value'] / metric_mean))
new_bar_df = pd.concat(new_bar_l)
# display(new_bar_df)
#     new_bar_df = bar_df.loc[idx[:, bar_df.index.get_level_values(1) == metric, :], 'Value'] / metric_mean
    
#     bar_df = bar_df[bar_df.loc[:, ['Metric']] == metric] * metric_mean
# display(bar_df.loc[idx[:, :, :], ['Value']])
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# display(scaler.fit_transform(new_bar_df.loc[idx[:, :, :], ['Value']]))
# final_bar_df['Value'] = scaler.fit_transform(new_bar_df.loc[idx[:, :, :], ['Value']])

final_bar_df['Z-score'] = normalize_df.loc[idx[:, :, :], ['Value']]
# final_bar_df['Value'] = new_bar_df.loc[idx[:, :, :], ['Value']]
final_bar_df.rename(index=metrics_of_interest)
# Out:
#                                                                                    Value
#                                     metric                       protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 buns_total                   combo_profile  0.158410
#                                                                  no_constraint  1.804591
#                                     int_area_total               combo_profile  0.505287
#                                                                  no_constraint  0.789358
#                                     int_energy_res_summary_delta combo_profile -0.729248
# ...                                                                                  ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  observed_evolution           no_constraint  0.812255
#                                     percent_int_area_hydrophobic combo_profile -1.458889
#                                                                  no_constraint -2.536411
#                                     shape_complementarity        combo_profile -0.504788
#                                                                  no_constraint -0.370576
#
# [9086 rows x 1 columns]
#                                                                                 Value  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint     2.642857
#                                                               Free           6.400000
#                                     Buried Surface Area (BSA) Constraint  1645.445243
#                                                               Free        1795.745410
#                                     Predicted Binding Energy  Constraint   -36.732404
# ...                                                                               ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free           1.000000
#                                     Hydrophobic BSA           Constraint     0.614864
#                                                               Free           0.541758
#                                     Shape Complementarity     Constraint     0.639006
#                                                               Free           0.649500
#
#                                                                                              Metric  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint      Buried Unsat. H-bonds
#                                                               Free            Buried Unsat. H-bonds
#                                     Buried Surface Area (BSA) Constraint  Buried Surface Area (BSA)
#                                                               Free        Buried Surface Area (BSA)
#                                     Predicted Binding Energy  Constraint   Predicted Binding Energy
# ...                                                                                             ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free            % Residues Obs. Evol.
#                                     Hydrophobic BSA           Constraint            Hydrophobic BSA
#                                                               Free                  Hydrophobic BSA
#                                     Shape Complementarity     Constraint      Shape Complementarity
#                                                               Free            Shape Complementarity
#
#                                                                             Protocol  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint  Constraint
#                                                               Free              Free
#                                     Buried Surface Area (BSA) Constraint  Constraint
#                                                               Free              Free
#                                     Predicted Binding Energy  Constraint  Constraint
# ...                                                                              ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free              Free
#                                     Hydrophobic BSA           Constraint  Constraint
#                                                               Free              Free
#                                     Shape Complementarity     Constraint  Constraint
#                                                               Free              Free
#
#                                                                            Z-score
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint  0.158410
#                                                               Free        1.804591
#                                     Buried Surface Area (BSA) Constraint  0.505287
#                                                               Free        0.789358
#                                     Predicted Binding Energy  Constraint -0.729248
# ...                                                                            ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free        0.812255
#                                     Hydrophobic BSA           Constraint -1.458889
#                                                               Free       -2.536411
#                                     Shape Complementarity     Constraint -0.504788
#                                                               Free       -0.370576
#
# [9086 rows x 4 columns]

# %%
def map_level(df, dct, level=0):
    index = df.index
    index.set_levels([[dct.get(item, item) for item in names] if i==level else names
                      for i, names in enumerate(index.levels)], inplace=True)

# %%
map_level(final_bar_df, metrics_of_interest, level=1)
map_level(final_bar_df, protocols_of_interest, level=2)

final_bar_df['Metric'] = final_bar_df.index.get_level_values(1)
final_bar_df['Protocol'] = final_bar_df.index.get_level_values(2)
                 
display(final_bar_df)
# Out:
#                                                                                 Value  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint     2.642857
#                                                               Free           6.400000
#                                     Buried Surface Area (BSA) Constraint  1645.445243
#                                                               Free        1795.745410
#                                     Predicted Binding Energy  Constraint   -36.732404
# ...                                                                               ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free           1.000000
#                                     Hydrophobic BSA           Constraint     0.614864
#                                                               Free           0.541758
#                                     Shape Complementarity     Constraint     0.639006
#                                                               Free           0.649500
#
#                                                                                              Metric  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint      Buried Unsat. H-bonds
#                                                               Free            Buried Unsat. H-bonds
#                                     Buried Surface Area (BSA) Constraint  Buried Surface Area (BSA)
#                                                               Free        Buried Surface Area (BSA)
#                                     Predicted Binding Energy  Constraint   Predicted Binding Energy
# ...                                                                                             ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free            % Residues Obs. Evol.
#                                     Hydrophobic BSA           Constraint            Hydrophobic BSA
#                                                               Free                  Hydrophobic BSA
#                                     Shape Complementarity     Constraint      Shape Complementarity
#                                                               Free            Shape Complementarity
#
#                                                                             Protocol  \
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint  Constraint
#                                                               Free              Free
#                                     Buried Surface Area (BSA) Constraint  Constraint
#                                                               Free              Free
#                                     Predicted Binding Energy  Constraint  Constraint
# ...                                                                              ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free              Free
#                                     Hydrophobic BSA           Constraint  Constraint
#                                                               Free              Free
#                                     Shape Complementarity     Constraint  Constraint
#                                                               Free              Free
#
#                                                                            Z-score
#                                     metric                    protocol
# 1lu9_2fw7-DEGEN_1_1-ROT_13_1-tx_166 Buried Unsat. H-bonds     Constraint  0.158410
#                                                               Free        1.804591
#                                     Buried Surface Area (BSA) Constraint  0.505287
#                                                               Free        0.789358
#                                     Predicted Binding Energy  Constraint -0.729248
# ...                                                                            ...
# 4f47_4grd-DEGEN_1_2-ROT_8_1-tx_618  % Residues Obs. Evol.     Free        0.812255
#                                     Hydrophobic BSA           Constraint -1.458889
#                                                               Free       -2.536411
#                                     Shape Complementarity     Constraint -0.504788
#                                                               Free       -0.370576
#
# [9086 rows x 4 columns]

# %% [markdown]
# ## Original view of all protocols
# I started with int_energy_context_delta, shape_complementarity, buns_total, contact_count', 'interaction_energy_complex', int_area_hydrophobic, int_area_polar, int_area_total, number_hbonds
#
# After analysis, it seems that some are not useful or the axis need to be moved to visualize. I am also trying different data shapes
#
# I have finally reworked this so that the values are comparable. Scaling by mean and SD of each allows comparisons to be made. I specifically looked at combo_profile (Constrained, Constraint) versus no_constraint (Unconstrained, Free) protocols

# %%
sns.distplot(final_bar_df[final_bar_df['Protocol'] == 'Free'][final_bar_df['Metric'] == 'Predicted Binding Energy']['Value'], color=sns.color_palette('colorblind')[1])
sns.distplot(final_bar_df[final_bar_df['Protocol'] == 'Constraint'][final_bar_df['Metric'] == 'Predicted Binding Energy']['Value'], color=sns.color_palette('colorblind')[0])
# sns.plot.show()
# Out:
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Value', ylabel='Density'>

# %%
ax = sns.distplot(final_bar_df[final_bar_df['Protocol'] == 'Constraint'][final_bar_df['Metric'] == 'Predicted Binding Energy']['Value'])
# Out:
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/kmeador14/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# plt.figure(figsize=(6, 4))
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ['Times New Roman']

with sns.plotting_context("notebook", font_scale=1.5):
    fig, ax = plt.subplots()

    sns.boxplot(y='Metric', hue='Protocol', x='Z-score', data=final_bar_df, 
                showfliers = False, palette=sns.color_palette('colorblind'),
                order=metrics_of_interest.values())
    ax.set_ylabel('')    
#     ax.set_xlabel('')
    plt.show()
with sns.plotting_context("notebook", font_scale=1):
    fig, ax = plt.subplots()

    sns.boxplot(y='Metric', hue='Protocol', x='Z-score', data=final_bar_df, 
                showfliers = False, palette=sns.color_palette('colorblind'),
                order=metrics_of_interest.values())
    ax.set_ylabel('')    
#     ax.set_xlabel('')
    plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
# plt.figure(figsize=(6, 4))
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ['Times New Roman']

with sns.plotting_context("notebook", font_scale=1.5):
    fig, ax = plt.subplots()

    sns.boxplot(y='Metric', hue='Protocol', x='Z-score', data=final_bar_df, 
                showfliers = False, palette=sns.color_palette('colorblind'),
                order=metrics_of_interest.values())
    ax.set_ylabel('')    
#     ax.set_xlabel('')
    plt.show()
with sns.plotting_context("notebook", font_scale=1):
    fig, ax = plt.subplots()

    sns.boxplot(y='Metric', hue='Protocol', x='Z-score', data=final_bar_df, 
                showfliers = False, palette=sns.color_palette('colorblind'),
                order=metrics_of_interest.values())
    ax.set_ylabel('')    
#     ax.set_xlabel('')
    plt.show()

# %%
protocol_specific_columns = ['int_energy_res_summary_delta', 'shape_complementarity',
                             'buns_total', 'contact_count', 'number_hbonds']
for metric in protocol_specific_columns:
# for protocol in unique_protocols:
    protocol_bar_df = bar_df[bar_df['Metric'] == metric]
#     plt.figure(figsize=(5, 5))
#     sns.barplot(x="metric", hue="protocol", y='Value', data=protocol_bar_df)
    sns.catplot(x="Protocol", y='Value', kind='box', data=protocol_bar_df)  # hue="protocol", ci='sd'
    print(metric)
    plt.show()

# %%
bsa_bar_df = pd.concat([bar_df[bar_df['Metric'] == 'int_area_hydrophobic'], bar_df[bar_df['Metric'] == 'int_area_polar'], bar_df[bar_df['Metric'] == 'int_area_total']])
# bar_df[bar_df['metric'] == 'int_area_hydrophobic']
# bar_df[bar_df['metric'] == 'int_area_polar']
# bar_df[bar_df['metric'] == 'int_area_total']
# display(bsa_bar_df)

# %%
# with SD
# plt.figure(figsize=(100, 6))
# sns.barplot(x="metric", hue="protocol", y='Value', ci='sd', data=bsa_bar_df)
sns.catplot(x='Metric', y='Value', hue='Protocol', kind='violin', aspect=2, data=bsa_bar_df)  # hue="protocol", ci='sd'
plt.show()

# with 95% confidence interval
plt.figure(figsize=(20, 6))
sns.barplot(x='Metric', hue='Protocol', y='Value', data=bsa_bar_df)
plt.show()

# %%
# .stack() takes a multiindex column header and re-orients (almost transposes) the data onto the index
bar_df = pd.DataFrame(seq_stats_protocol_df.stack().stack())
bar_df['Metric'] = bar_df.index.get_level_values(1)
bar_df['Protocol'] = bar_df.index.get_level_values(2)
bar_df = bar_df.rename({0: 'Value'}, axis=1)
display(bar_df)

# %%
divergence_bar_df = pd.concat([bar_df[bar_df['Metric'] == 'divergence_interface_per_res'], bar_df[bar_df['Metric'] == 'divergence_evolution_per_res']])
box = sns.catplot(x="Metric", y='Value', hue="Protocol", kind='box', aspect=2, data=divergence_bar_df)  #  ci='sd'
# ax = sns.boxplot(x="metric", y='Value', hue="protocol", data=divergence_bar_df)  #, ax=box.ax)  #  ci='sd'
# ax = sns.swarmplot(x="metric", y='Value', hue="protocol", data=divergence_bar_df)  #, ax=box.ax)  #  ci='sd'

# %%
seq_specific_columns = ['divergence_interface_per_res', 'divergence_evolution_per_res']
# display(bar_df)
combo_favor_combined_df = pd.concat([bar_df[bar_df['protocol'] == 'combo_profile'], bar_df[bar_df['protocol'] == 'favor_profile']])
combo_favor_combined_df['protocol'] = 'combination'
bar_df = pd.concat([bar_df, combo_favor_combined_df])
for metric in seq_specific_columns:
# for protocol in unique_protocols:
    protocol_bar_df = bar_df[bar_df['metric'] == metric]
#     plt.figure(figsize=(5, 5))
#     sns.barplot(x="metric", hue="protocol", y='Value', data=protocol_bar_df)
    sns.catplot(x="protocol", y='Value', kind='box', aspect=2, data=protocol_bar_df)  # hue="protocol", ci='sd'
    print(metric)
    plt.show()

# %% [markdown]
# ## Need to add a couple of metrics to the Dataframe. All subsets are missing these...

# %%
only_metrics_protocol_df = xtal_pose_df.droplevel(0, axis=1)
# only_metrics_protocol_df = columns_to_new_column(only_metrics_protocol_df, division_pairs, mode='truediv')
# display(only_metrics_protocol_df)
# only_metrics_protocol_df['percent_int_area_polar']

# %% [markdown]
# ## Filtering by additional design filters which lead to good poses

# %% [markdown]
# I am going to remove designs not satisfying a couple of criteria that have been useful in past design work. This includes:
#
# buried unsatisfied hydrogen bonds (Stranges and Khulman 2013): 2/1000A
#
# percent polar interface area (): >30%
#
# NOT YET number of h bonds: <10 <8?

# %%
design_requirements = {'percent_int_area_polar': 0.4, 'buns_per_ang': 0.002}  #, 'number_hbonds': 10}
design_requirements.update(crystal_means)

# %%
crystal_filters = {column: {'direction': filter_key_df.loc['direction', column], 'value': design_requirements[column]} 
                   for column in design_requirements}

print('Starting designs = %d' % len(only_metrics_protocol_df))
print('Using filter parameters: %s' % str(crystal_filters))
crystal_filters_with_idx = df_filter_index_by_value(only_metrics_protocol_df, **crystal_filters)
# Take a df and retrieve the indices which have column values greater_equal/less_equal to a value depending
# on whether the column should be sorted max/min
# Args:
#     df (pandas.DataFrame): DataFrame to filter indices on
# Keyword Args:
#     kwargs (dict): {column: {'direction': 'min', 'value': 0.3, 'idx': ['0001', '0002', ...]}, ...}
for _filter in crystal_filters_with_idx:
    print('%s designs = %d' % (_filter, len(crystal_filters_with_idx[_filter]['idx'])))

# %%
# print(crystal_filters_with_idx)
design_indices = {_filter: crystal_filters_with_idx[_filter]['idx'] for _filter in crystal_filters_with_idx}
# display(design_indices[0])
symmetry_and_design_filtered_idx = index_intersection(design_indices)
print('Final number of designs passing all metrics is %d' % len(symmetry_and_design_filtered_idx))
symmetry_and_design_filtered_df = only_metrics_protocol_df.loc[symmetry_and_design_filtered_idx, :]

# %%
metrics = {'average_fragment_z_score': 'The average fragment z-value used in docking/design',
                 'buns_heavy_total': 'Buried unsaturated H-bonding heavy atoms in the design',
                 'buns_hpol_total': 'Buried unsaturated H-bonding polarized hydrogen atoms in the design',
                 'buns_total': 'Total buried unsaturated H-bonds in the design',
                 'buns_per_ang': 'Buried Unsaturated Hbonds per Angstrom^2 of interface',
                 'component_1_symmetry': 'The symmetry group of component 1',
                 'component_1_name': 'component 1 PDB_ID',
                 'component_1_number_of_residues': 'The number of residues in the monomer of component 1',
                 'component_1_max_radius': 'The maximum distance that component 1 reaches away from the center of mass',
                 'component_1_n_terminal_helix': 'Whether the n-terminus has an alpha helix',
                 'component_1_c_terminal_helix': 'Whether the c-terminus has an alpha helix',
                 'component_1_n_terminal_orientation':
                     'The direction the n-terminus is oriented from the symmetry group center of mass. 1 is away, -1 is'
                     ' towards',
                 'component_1_c_terminal_orientation':
                     'The direction the c-terminus is oriented from the symmetry group center of mass. 1 is away, -1 is'
                     ' towards',
                 'component_2_symmetry': 'The symmetry group of component 2',
                 'component_2_name': 'component 2 PDB_ID',
                 'component_2_number_of_residues': 'The number of residues in the monomer of component 2',
                 'component_2_max_radius': 'The maximum distance that component 2 reaches away from the center of mass',
                 'component_2_n_terminal_helix': 'Whether the n-terminus has an alpha helix',
                 'component_2_c_terminal_helix': 'Whether the c-terminus has an alpha helix',
                 'component_2_n_terminal_orientation':
                     'The direction the n-terminus is oriented from the symmetry group center of mass. 1 is away, -1 is'
                     ' towards',
                 'component_2_c_terminal_orientation':
                     'The direction the c-terminus is oriented from the symmetry group center of mass. 1 is away, -1 is'
                     ' towards',
                 'contact_count': 'Number of carbon-carbon contacts across interface',
                 'core': 'The number of \'core\' residues as classified by E. Levy 2010',
                 'cst_weight': 'Total weight of coordinate constraints to keep design from moving in cartesian space',
                 'divergence_combined_per_residue': 'The Jensen-Shannon divergence of interface residues from the'
                                                    ' position specific design profile values. Includes fragment & '
                                                    'evolution if both are True, otherwise only includes those '
                                                    'specified for use in design.',
                 'divergence_fragment_per_residue': 'The Jensen-Shannon divergence of interface residues from the'
                                                    ' position specific fragment profile',
                 'divergence_evolution_per_residue': 'The Jensen-Shannon divergence of interface residues from the'
                                                     ' position specific evolutionary profile',
                 'divergence_interface_per_residue': 'The Jensen-Shannon divergence of interface residues from the'
                                                     ' typical interface background',
                 'fsp_energy': 'Total weight of sequence constraints used to favor certain amino acids in design. '
                               'Only protocols with a favored profile have values',
                 'int_area_hydrophobic': 'Total hydrophobic interface buried surface area',
                 'int_area_polar': 'Total polar interface buried surface area',
                 'int_area_res_summary_hydrophobic_1_unbound': 
                     'Sum of each interface residue\'s hydrophobic area for interface1',
                 'int_area_res_summary_hydrophobic_2_unbound': 
                     'Sum of each interface residue\'s hydrophobic area for interface2',
                 'int_area_res_summary_polar_1_unbound': 'Sum of each interface residue\'s polar area for interface1',
                 'int_area_res_summary_polar_2_unbound': 'Sum of each interface residue\'s polar area for interface2',
                 'int_area_res_summary_total_1_unbound': 'Sum of each interface residue\'s total area for interface1',
                 'int_area_res_summary_total_2_unbound': 'Sum of each interface residue\'s total area for interface2',
                 'int_area_total': 'Total interface buried surface area',
                 'int_composition_similarity':
                     'The similarity to the expected interface composition given interface buried surface area. '
                     '1 is similar to natural interfaces, 0 is dissimilar',
                 'int_connectivity_1': 'How embedded is interface1 in the rest of the protein?',
                 'int_connectivity_2': 'How embedded is interface2 in the rest of the protein?',
                 'int_energy_res_summary_complex': 'Total interface residue energies in the complexed state',
                 'int_energy_res_summary_delta': 'deltaG of int_energy_res_summary_complex and _unbound',
                 'int_energy_res_summary_unbound': 'Total interface residue energies in the unbound state',
                 'int_energy_res_summary_1_unbound': 'Sum of interface1 residue energies in the unbound state',
                 'int_energy_res_summary_2_unbound': 'Sum of interface2 residue energies in the unbound state',
                 'int_separation': 'Median distance between all atom points on each side of the interface',
                 'interaction_energy_complex': 'The two-body (residue-pair) energy of the complexed interface. '
                                               'No solvation energies',
                 'interface_b_factor_per_res': 'The average B-factor from each atom, from each interface residue',
                 'multiple_fragment_ratio': 'The extent to which fragment observations are connected in the interface.'
                                            ' Higher ratio means multiple fragment observations per residue',
                 'number_hbonds': 'The number of residues making H-bonds in the total interface. Residues may make more'
                                  ' than one H-bond',
                 'nanohedra_score': 'Sum of total fragment containing residue match scores (1 / 1 + Z-score^2) weighted'
                                    ' by their ranked match score. Maximum of 2/residue',
                 'nanohedra_score_center': 'nanohedra_score for the central fragment residues only',
                 'nanohedra_score_per_res': 'The Nanohedra Score normalized by number of fragment residues',
                 'nanohedra_score_center_per_res_center':
                     'The central Nanohedra Score normalized by number of central fragment residues',
                 'number_fragment_residues_total': 'The number of residues in the interface with fragment observations'
                                                   'found',
                 'number_fragment_residues_center': 'The number of residues in the interface that are the central '
                                                     'fragment observation',
                 'observations': 'Number of unique design trajectories contributing to statistics',
                 'observed_design': 'Percent of observed residues in combined profile. 1 is 100%',
                 'observed_evolution': 'Percent of observed residues in evolutionary profile. 1 is 100%',
                 'observed_interface': 'Percent of observed residues in fragment profile. 1 is 100%',
                 'percent_core': 'The percentage of total residues which are \'core\' according to Levy, E. 2010',
                 'percent_fragment': 'Percent of residues with fragment data out of total residues',
                 'percent_fragment_coil': 'The percentage of fragments represented from coiled SS elements',
                 'percent_fragment_helix': 'The percentage of fragments represented from an a-helix SS elements',
                 'percent_fragment_strand': 'The percentage of fragments represented from a b-strand SS elements',
                 'percent_int_area_hydrophobic': 'The percent of interface area which is occupied by hydrophobic atoms',
                 'percent_int_area_polar': 'The percent of interface area which is occupied by polar atoms',
                 'percent_rim': 'The percentage of total residues which are \'rim\' according to Levy, E. 2010',
                 'percent_support': 'The percentage of total residues which are \'support\' according to Levy, E. 2010',
                 'protocol_energy_distance_sum':
                     'The distance between the average linearly embedded per residue energy co-variation between '
                     'specified protocols. Larger = greater distance. A small distance indicates that different '
                     'protocols arrived at the same per residue energy conclusions despite different pools of amino '
                     'acids specified for sampling',
                 'protocol_similarity_sum':
                     'The statistical similarity between all sampled protocols. Larger is more similar, indicating that'
                     ' different protocols have interface statistics that are similar despite different pools of amino '
                     'acids specified for sampling',
                 'protocol_seq_distance_sum':
                     'The distance between the average linearly embedded sequence differences between specified '
                     'protocols. Larger = greater distance. A small distance indicates that different '
                     'protocols arrived at the same per residue energy conclusions despite different pools of amino '
                     'acids specified for sampling',
                 'ref': 'Rosetta Energy Term - A metric for the unfolded energy of the protein along with sequence '
                        'fitting corrections',
                 'rim': 'The number of \'rim\' residues as classified by E. Levy 2010',
                 'rmsd': 'Root Mean Square Deviation of all CA atoms between the refined (relaxed) and designed states',
                 'protocol': 'Protocols utilized to search sequence space given fragment and/or evolutionary constraint '
                         'information',
                 'shape_complementarity': 'Interface shape complementarity (SC). Measure of fit between two surfaces',
                 'solvation_energy': 'Energy required to hydrate the unbound components',
                 'support': 'The number of \'support\' residues as classified by E. Levy 2010',
                 'symmetry': 'The specific symmetry type used design (point (0), layer (2), lattice(3))',
                 'fragment_z_score_total': 'The sum of all fragments z-values',
                 'number_of_fragments': 'The number of fragments found in the pose interface',
                 'total_interface_residues':
                     'The total number of interface residues found in the pose (residue CB within 8A)',
                 'REU': 'Rosetta Energy Units. Always 0. We can disregard',
                 'coordinate_constraint': 'Same as cst_weight',
                 'res_type_constraint': 'Same as fsp_energy',
                 'time': 'Time for the protocol to complete',
                 'hbonds_res_selection_unbound': 'The specific h-bonds present in the bound pose',
                 'hbonds_res_selection_1_unbound': 'The specific h-bonds present in the unbound interface1',
                 'hbonds_res_selection_2_unbound': 'The specific h-bonds present in the unbound interface2',
                 'dslf_fa13': 'Rosetta Energy Term - disulfide bonding',
                 'fa_atr': 'Rosetta Energy Term - lennard jones full atom atractive forces',
                 'fa_dun': 'Rosetta Energy Term - dunbrack rotamer library statistical probability',
                 'fa_elec': 'Rosetta Energy Term - full atom electrostatic forces',
                 'fa_intra_rep': 'Rosetta Energy Term - lennard jones full atom intra-residue repulsive forces',
                 'fa_intra_sol_xover4': 'Rosetta Energy Term - full atom intra-residue solvent forces',
                 'fa_rep': 'Rosetta Energy Term - lennard jones full atom repulsive forces',
                 'fa_sol': 'Rosetta Energy Term - full atom solvent forces',
                 'hbond_bb_sc': 'Rosetta Energy Term - backbone/sidechain hydrogen bonding',
                 'hbond_lr_bb': 'Rosetta Energy Term - long range backbone hydrogen bonding',
                 'hbond_sc': 'Rosetta Energy Term - side-chain hydrogen bonding',
                 'hbond_sr_bb': 'Rosetta Energy Term - short range backbone hydrogen bonding',
                 'lk_ball_wtd': 'Rosetta Energy Term - Lazaris-Karplus weighted anisotropic solvation energy?',
                 'omega': 'Rosetta Energy Term - Lazaris-Karplus weighted anisotropic solvation energy?',
                 'p_aa_pp': '"Rosetta Energy Term - statistical probability of an amino acid given angles phi',
                 'pro_close': 'Rosetta Energy Term - to favor closing of proline rings',
                 'rama_prepro': 'Rosetta Energy Term - amino acid dependent term to favor certain ramachandran angles '
                                'on residue before prolines',
                 'yhh_planarity': 'Rosetta Energy Term - to favor planarity of tyrosine hydrogen'}

# %%
new_metrics = {}
for key, value in metrics.items():
    try:
        new_metrics[key] = {'description': value, 
                            'direction': filter_key_df.loc['direction', key], 
                            'function': filter_key_df.loc['function', key], 
                            'filter': bool(filter_key_df.loc['filter', key])}
    except KeyError:
        new_metrics[key] = {'description': value, 'direction': None,
                            'function': None, 'filter': None}
        print(key)
# Out:
# component_1_name
# component_1_max_radius
# component_1_n_terminal_helix
# component_1_c_terminal_helix
# component_1_n_terminal_orientation
# component_1_c_terminal_orientation
# component_2_name
# component_2_max_radius
# component_2_n_terminal_helix
# component_2_c_terminal_helix
# component_2_n_terminal_orientation
# component_2_c_terminal_orientation
# divergence_combined_per_residue
# divergence_fragment_per_residue
# divergence_evolution_per_residue
# divergence_interface_per_residue
# int_energy_res_summary_2_unbound
# nanohedra_score_center
# nanohedra_score_center_per_res_center
# number_fragment_residues_center
# observed_interface
# protocol
# symmetry
# fragment_z_score_total
# number_of_fragments
# REU
# coordinate_constraint
# res_type_constraint
# time
# hbonds_res_selection_unbound
# hbonds_res_selection_1_unbound
# hbonds_res_selection_2_unbound
# dslf_fa13
# fa_atr
# fa_dun
# fa_elec
# fa_intra_rep
# fa_intra_sol_xover4
# fa_rep
# fa_sol
# hbond_bb_sc
# hbond_lr_bb
# hbond_sc
# hbond_sr_bb
# lk_ball_wtd
# omega
# p_aa_pp
# pro_close
# rama_prepro
# yhh_planarity

# %%
pd.DataFrame(new_metrics)
# Out:
#                                       average_fragment_z_score  \
# description  The average fragment z-value used in docking/d...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                               buns_heavy_total  \
# description  Buried unsaturated H-bonding heavy atoms in th...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                                buns_hpol_total  \
# description  Buried unsaturated H-bonding polarized hydroge...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                                  buns_total  \
# description  Total buried unsaturated H-bonds in the design
# direction                                               min
# function                                               rank
# filter                                                 True
#
#                                                   buns_per_ang  \
# description  Buried Unsaturated Hbonds per Angstrom^2 of in...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                           component_1_symmetry    component_1_name  \
# description  The symmetry group of component 1  component 1 PDB_ID
# direction                                  min                None
# function                                equals                None
# filter                                    True                None
#
#                                 component_1_number_of_residues  \
# description  The number of residues in the monomer of compo...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                         component_1_max_radius  \
# description  The maximum distance that component 1 reaches ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                           component_1_n_terminal_helix  \
# description  Whether the n-terminus has an alpha helix
# direction                                         None
# function                                          None
# filter                                            None
#
#                           component_1_c_terminal_helix  \
# description  Whether the c-terminus has an alpha helix
# direction                                         None
# function                                          None
# filter                                            None
#
#                             component_1_n_terminal_orientation  \
# description  The direction the n-terminus is oriented from ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                             component_1_c_terminal_orientation  \
# description  The direction the c-terminus is oriented from ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                           component_2_symmetry    component_2_name  \
# description  The symmetry group of component 2  component 2 PDB_ID
# direction                                  min                None
# function                                equals                None
# filter                                    True                None
#
#                                 component_2_number_of_residues  \
# description  The number of residues in the monomer of compo...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                         component_2_max_radius  \
# description  The maximum distance that component 2 reaches ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                           component_2_n_terminal_helix  \
# description  Whether the n-terminus has an alpha helix
# direction                                         None
# function                                          None
# filter                                            None
#
#                           component_2_c_terminal_helix  \
# description  Whether the c-terminus has an alpha helix
# direction                                         None
# function                                          None
# filter                                            None
#
#                             component_2_n_terminal_orientation  \
# description  The direction the n-terminus is oriented from ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                             component_2_c_terminal_orientation  \
# description  The direction the c-terminus is oriented from ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                  contact_count  \
# description  Number of carbon-carbon contacts across interface
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                           core  \
# description  The number of 'core' residues as classified by...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                     cst_weight  \
# description  Total weight of coordinate constraints to keep...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                divergence_combined_per_residue  \
# description  The Jensen-Shannon divergence of interface res...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                divergence_fragment_per_residue  \
# description  The Jensen-Shannon divergence of interface res...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                               divergence_evolution_per_residue  \
# description  The Jensen-Shannon divergence of interface res...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                               divergence_interface_per_residue  \
# description  The Jensen-Shannon divergence of interface res...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                     fsp_energy  \
# description  Total weight of sequence constraints used to f...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                         int_area_hydrophobic  \
# description  Total hydrophobic interface buried surface area
# direction                                                min
# function                                                rank
# filter                                                  True
#
#                                         int_area_polar  \
# description  Total polar interface buried surface area
# direction                                          max
# function                                          rank
# filter                                            True
#
#                     int_area_res_summary_hydrophobic_1_unbound  \
# description  Sum of each interface residue's hydrophobic ar...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                     int_area_res_summary_hydrophobic_2_unbound  \
# description  Sum of each interface residue's hydrophobic ar...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                           int_area_res_summary_polar_1_unbound  \
# description  Sum of each interface residue's polar area for...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                           int_area_res_summary_polar_2_unbound  \
# description  Sum of each interface residue's polar area for...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                           int_area_res_summary_total_1_unbound  \
# description  Sum of each interface residue's total area for...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                           int_area_res_summary_total_2_unbound  \
# description  Sum of each interface residue's total area for...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                   int_area_total  \
# description  Total interface buried surface area
# direction                                    max
# function                                    rank
# filter                                      True
#
#                                     int_composition_similarity  \
# description  The similarity to the expected interface compo...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                             int_connectivity_1  \
# description  How embedded is interface1 in the rest of the ...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                             int_connectivity_2  \
# description  How embedded is interface2 in the rest of the ...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                 int_energy_res_summary_complex  \
# description  Total interface residue energies in the comple...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                   int_energy_res_summary_delta  \
# description  deltaG of int_energy_res_summary_complex and _...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                 int_energy_res_summary_unbound  \
# description  Total interface residue energies in the unboun...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                               int_energy_res_summary_1_unbound  \
# description  Sum of interface1 residue energies in the unbo...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                               int_energy_res_summary_2_unbound  \
# description  Sum of interface2 residue energies in the unbo...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                 int_separation  \
# description  Median distance between all atom points on eac...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                     interaction_energy_complex  \
# description  The two-body (residue-pair) energy of the comp...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                     interface_b_factor_per_res  \
# description  The average B-factor from each atom, from each...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                        multiple_fragment_ratio  \
# description  The extent to which fragment observations are ...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                  number_hbonds  \
# description  The number of residues making H-bonds in the t...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                nanohedra_score  \
# description  Sum of total fragment containing residue match...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                         nanohedra_score_center  \
# description  nanohedra_score for the central fragment resid...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                        nanohedra_score_per_res  \
# description  The Nanohedra Score normalized by number of fr...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                          nanohedra_score_center_per_res_center  \
# description  The central Nanohedra Score normalized by numb...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                 number_fragment_residues_total  \
# description  The number of residues in the interface with f...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                number_fragment_residues_center  \
# description  The number of residues in the interface that a...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                   observations  \
# description  Number of unique design trajectories contribut...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                observed_design  \
# description  Percent of observed residues in combined profi...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                             observed_evolution  \
# description  Percent of observed residues in evolutionary p...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                             observed_interface  \
# description  Percent of observed residues in fragment profi...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                   percent_core  \
# description  The percentage of total residues which are 'co...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                               percent_fragment  \
# description  Percent of residues with fragment data out of ...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                          percent_fragment_coil  \
# description  The percentage of fragments represented from c...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                         percent_fragment_helix  \
# description  The percentage of fragments represented from a...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                        percent_fragment_strand  \
# description  The percentage of fragments represented from a...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                   percent_int_area_hydrophobic  \
# description  The percent of interface area which is occupie...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                         percent_int_area_polar  \
# description  The percent of interface area which is occupie...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                                    percent_rim  \
# description  The percentage of total residues which are 'ri...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                                percent_support  \
# description  The percentage of total residues which are 'su...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                   protocol_energy_distance_sum  \
# description  The distance between the average linearly embe...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                        protocol_similarity_sum  \
# description  The statistical similarity between all sampled...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                      protocol_seq_distance_sum  \
# description  The distance between the average linearly embe...
# direction                                                  min
# function                                                  rank
# filter                                                    True
#
#                                                            ref  \
# description  Rosetta Energy Term - A metric for the unfolde...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                            rim  \
# description  The number of 'rim' residues as classified by ...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                           rmsd  \
# description  Root Mean Square Deviation of all CA atoms bet...
# direction                                                  min
# function                                             normalize
# filter                                                    True
#
#                                                       protocol  \
# description  Protocols utilized to search sequence space gi...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                          shape_complementarity  \
# description  Interface shape complementarity (SC). Measure ...
# direction                                                  max
# function                                             normalize
# filter                                                    True
#
#                                               solvation_energy  \
# description  Energy required to hydrate the unbound components
# direction                                                  min
# function                                                rank\n
# filter                                                    True
#
#                                                        support  \
# description  The number of 'support' residues as classified...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                       symmetry  \
# description  The specific symmetry type used design (point ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                         fragment_z_score_total  \
# description  The sum of all fragments z-values
# direction                                 None
# function                                  None
# filter                                    None
#
#                                            number_of_fragments  \
# description  The number of fragments found in the pose inte...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                       total_interface_residues  \
# description  The total number of interface residues found i...
# direction                                                  max
# function                                                  rank
# filter                                                    True
#
#                                                           REU  \
# description  Rosetta Energy Units. Always 0. We can disregard
# direction                                                None
# function                                                 None
# filter                                                   None
#
#             coordinate_constraint res_type_constraint  \
# description    Same as cst_weight  Same as fsp_energy
# direction                    None                None
# function                     None                None
# filter                       None                None
#
#                                           time  \
# description  Time for the protocol to complete
# direction                                 None
# function                                  None
# filter                                    None
#
#                                hbonds_res_selection_unbound  \
# description  The specific h-bonds present in the bound pose
# direction                                              None
# function                                               None
# filter                                                 None
#
#                                 hbonds_res_selection_1_unbound  \
# description  The specific h-bonds present in the unbound in...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                 hbonds_res_selection_2_unbound  \
# description  The specific h-bonds present in the unbound in...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                            dslf_fa13  \
# description  Rosetta Energy Term - disulfide bonding
# direction                                       None
# function                                        None
# filter                                          None
#
#                                                         fa_atr  \
# description  Rosetta Energy Term - lennard jones full atom ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                         fa_dun  \
# description  Rosetta Energy Term - dunbrack rotamer library...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                        fa_elec  \
# description  Rosetta Energy Term - full atom electrostatic ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                   fa_intra_rep  \
# description  Rosetta Energy Term - lennard jones full atom ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                            fa_intra_sol_xover4  \
# description  Rosetta Energy Term - full atom intra-residue ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                         fa_rep  \
# description  Rosetta Energy Term - lennard jones full atom ...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                      fa_sol  \
# description  Rosetta Energy Term - full atom solvent forces
# direction                                              None
# function                                               None
# filter                                                 None
#
#                                                    hbond_bb_sc  \
# description  Rosetta Energy Term - backbone/sidechain hydro...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                    hbond_lr_bb  \
# description  Rosetta Energy Term - long range backbone hydr...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                       hbond_sc  \
# description  Rosetta Energy Term - side-chain hydrogen bonding
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                    hbond_sr_bb  \
# description  Rosetta Energy Term - short range backbone hyd...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                    lk_ball_wtd  \
# description  Rosetta Energy Term - Lazaris-Karplus weighted...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                          omega  \
# description  Rosetta Energy Term - Lazaris-Karplus weighted...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                        p_aa_pp  \
# description  "Rosetta Energy Term - statistical probability...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                      pro_close  \
# description  Rosetta Energy Term - to favor closing of prol...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                    rama_prepro  \
# description  Rosetta Energy Term - amino acid dependent ter...
# direction                                                 None
# function                                                  None
# filter                                                    None
#
#                                                  yhh_planarity
# description  Rosetta Energy Term - to favor planarity of ty...
# direction                                                 None
# function                                                  None
# filter                                                    None
